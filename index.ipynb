# %% [markdown]
# # Network Dynamics: Node Centrality - Lab
#
# ## Introduction
#
# In this lab, you'll get a chance to practice implementing and interpreting the centrality metrics discussed in the previous lesson by investigating the social network from Game of Thrones!
#
# ## Objectives
# You will be able to:
# - Compare and calculate degree, closeness, betweenness, and eigenvector centrality measures
# - Interpret characteristics of certain nodes based on their centrality metrics

# %% [markdown]
# ## Character Interaction Graph Data
#
# A. J. Beveridge and J. Shan created a network from George R. Martin's "A song of ice and fire" by extracting relationships between characters of the story. [The dataset is available at Github](https://github.com/mathbeveridge/asoiaf). Relationships between characters were formed every time a character's name appears within 15 words of another character. This was designed as an approximate metric for character's interactions with each other. The results of this simple analysis are quite profound and produce interesting visuals such as this graph:
#
# <img src="images/got.png" width=800>
#
# With that, it's your turn to start investigating the most central characters!

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
# %matplotlib inline
# Out:
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ##  Load the dataset
#
# Start by loading the dataset as a pandas DataFrame. From this, you'll then create a network representation of the dataset using NetworkX.
#
# The dataset is stored in the file `'asoiaf-all-edges.csv'`.

# %%
# Load edges into dataframes
df = pd.read_csv('asoiaf-all-edges.csv')

# Print the first five rows
df.head()
# Out:
#            Source            Target        Type  id  weight
# 0  Addam-Marbrand     Brynden-Tully  Undirected   0       3
# 1  Addam-Marbrand  Cersei-Lannister  Undirected   1       3
# 2  Addam-Marbrand       Gyles-Rosby  Undirected   2       3
# 3  Addam-Marbrand   Jaime-Lannister  Undirected   3      14
# 4  Addam-Marbrand      Jalabhar-Xho  Undirected   4       3

# %% [markdown]
# ## Create a Graph
#
# - Instantiate an empty graph
# - Iterate through the data and create appropriate edges to the empty graph you instantiated above. Be sure to add the weight to each edge

# %%
# Create an empty graph instance
G = nx.Graph()

# Read edge lists into dataframes
for row in df.index:
    source = df['Source'][row]
    target = df['Target'][row]
    weight = df['weight'][row]
    G.add_edge(source, target, weight=weight)

# %% [markdown]
# ## Calculate Degree
#
# To start the investigation of the most central characters in the books, calculate the degree centrality for each character. Then create a bar graph of the top 10 characters according to degree centrality.

# %%
# Your code here
pd.DataFrame.from_dict(nx.degree_centrality(G), orient='index').sort_values(by=0, ascending=False).head(10).plot(kind='barh')

# %% [markdown]
# ## Closeness Centrality
#
# Repeat the above exercise for the top 10 characters according to closeness centrality.

# %%
# Your code here
pd.DataFrame.from_dict(nx.closeness_centrality(G), orient='index').sort_values(by=0, ascending=False).head(10).plot(kind='barh')

# %% [markdown]
# ## Betweeness Centrality
#
# Repeat the process one more time for betweeness centrality.

# %%
# Your code here
pd.DataFrame.from_dict(nx.betweenness_centrality(G), orient='index').sort_values(by=0, ascending=False).head(10).plot(kind='barh')

# %% [markdown]
# ## Putting it All Together
#
# Great! Now put all of these metrics together along with eigenvector centrality. Combine all four metrics into a single dataframe for each character.

# %%
# Your code here
degrees = nx.degree_centrality(G)
closeness = nx.closeness_centrality(G)
betweeness = nx.betweenness_centrality(G)
eigs = nx.eigenvector_centrality(G)
centrality = pd.DataFrame([degrees, closeness, betweeness, eigs]).transpose()
centrality.columns = ['degrees', 'closeness', 'betweeness', 'eigs']
centrality = centrality.sort_values(by='eigs', ascending=False)
centrality.head()
# Out:
#                     degrees  closeness  betweeness      eigs
# Tyrion-Lannister   0.153459   0.476333    0.162191  0.251558
# Cersei-Lannister   0.122013   0.454545    0.088704  0.235771
# Jaime-Lannister    0.127044   0.451961    0.100838  0.226339
# Joffrey-Baratheon  0.086792   0.433952    0.031759  0.214376
# Sansa-Stark        0.094340   0.433007    0.048691  0.205842

# %% [markdown]
# ## Identifying Key Players
#
# While centrality can tell us a lot, you've also begun to see how certain individuals may not be the most central characters, but can be pivotal in the flow of information from one community to another. In the previous lesson, such nodes were labeled as 'bridges' acting as the intermediaries between two clusters. Try and identify such characters from this dataset.

# %%
# Your code here
centrality['bridge proxy'] = centrality['betweeness'] / centrality['degrees']
centrality = centrality.sort_values(by='bridge proxy', ascending=False)
centrality.head()
# Out:
#                 degrees  closeness  betweeness      eigs  bridge proxy
# Aggar          0.005031   0.269036    0.007997  0.001665      1.589358
# Alleras        0.010063   0.272915    0.014199  0.002928      1.411040
# Theon-Greyjoy  0.083019   0.423323    0.111283  0.102481      1.340458
# Jon-Snow       0.143396   0.445378    0.192120  0.144211      1.339782
# Cutjack        0.003774   0.255135    0.005028  0.001404      1.332494

# %% [markdown]
# ## Drawing the Graph
#
# To visualize all of these relationships, draw a graph of the network.

# %%
# Your code here
edge_labels = nx.get_edge_attributes(G, 'weight')
plt.figure(figsize=(12,12))
nx.draw(G, with_labels=True, pos=nx.spring_layout(G), alpha=0.8, node_color='#1cf0c7', node_size=700)
nx.draw_networkx_edge_labels(G, pos=nx.spring_layout(G), edge_labels=edge_labels)
# Out:
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# {('Addam-Marbrand',
#   'Brynden-Tully'): Text(0.08016349002718925, -0.005633294582366943, '3'),
#  ('Addam-Marbrand',
#   'Cersei-Lannister'): Text(0.07497981563210487, 0.04757401719689369, '3'),
#  ('Addam-Marbrand',
#   'Gyles-Rosby'): Text(0.0924898236989975, 0.061860740184783936, '3'),
#  ('Addam-Marbrand',
#   'Jaime-Lannister'): Text(0.09119170531630516, 0.01700055436231196, '14'),
#  ('Addam-Marbrand',
#   'Jalabhar-Xho'): Text(0.1672571897506714, 0.08337952569127083, '3'),
#  ('Addam-Marbrand',
#   'Joffrey-Baratheon'): Text(0.05426046787761152, 0.03631403297185898, '3'),
#  ('Addam-Marbrand',
#   'Kevan-Lannister'): Text(0.08979811519384384, 0.024108849465847015, '3'),
#  ('Addam-Marbrand',
#   'Lyle-Crakehall'): Text(0.12159184366464615, 0.00429154559969902, '4'),
#  ('Addam-Marbrand',
#   'Oberyn-Martell'): Text(0.0500493774889037, 0.07859012857079506, '3'),
#  ('Addam-Marbrand',
#   'Tyrion-Lannister'): Text(0.07130593061447144, 0.05082824267446995, '7'),
#  ('Addam-Marbrand',
#   'Tywin-Lannister'): Text(0.07550159469246864, 0.023720088647678494, '6'),
#  ('Addam-Marbrand',
#   'Varys'): Text(0.07114780135452747, 0.05184314027428627, '4'),
#  ('Brynden-Tully',
#   'Arya-Stark'): Text(-0.007324345409870148, -0.021985268453136086, '4'),
#  ('Brynden-Tully',
#   'Catelyn-Stark'): Text(0.05184190906584263, -0.043516770005226135, '29'),
#  ('Brynden-Tully',
#   'Daven-Lannister'): Text(0.11023292317986488, -0.06060584634542465, '3'),
#  ('Brynden-Tully',
#   'Edmure-Tully'): Text(0.06356889754533768, -0.056718576699495316, '24'),
#  ('Brynden-Tully',
#   'Edwyn-Frey'): Text(0.10249092057347298, -0.08554350584745407, '3'),
#  ('Brynden-Tully',
#   'Emmon-Frey'): Text(0.0982285924255848, -0.07362229377031326, '7'),
#  ('Brynden-Tully',
#   'Hoster-Tully'): Text(0.06573084741830826, -0.052895860746502876, '5'),
#  ('Brynden-Tully',
#   'Jaime-Lannister'): Text(0.06841280311346054, -0.029034891864284873, '29'),
#  ('Brynden-Tully',
#   'Lyle-Crakehall'): Text(0.09881294146180153, -0.04174390062689781, '4'),
#  ('Brynden-Tully',
#   'Lysa-Arryn'): Text(0.06868955120444298, -0.011854608543217182, '10'),
#  ('Brynden-Tully',
#   'Nestor-Royce'): Text(0.08289643377065659, 0.001926921308040619, '3'),
#  ('Brynden-Tully',
#   'Rickard-Karstark'): Text(0.043726599775254726, -0.07444283366203308, '4'),
#  ('Brynden-Tully',
#   'Robb-Stark'): Text(0.029606298950966448, -0.059804171323776245, '27'),
#  ('Brynden-Tully',
#   'Ryman-Frey'): Text(0.07363284379243851, -0.08035365492105484, '3'),
#  ('Brynden-Tully',
#   'Theon-Greyjoy'): Text(0.011809630319476128, -0.11617917194962502, '6'),
#  ('Brynden-Tully',
#   'Tyrion-Lannister'): Text(0.048527028411626816, 0.0047927964478731155, '4'),
#  ('Brynden-Tully',
#   'Tywin-Lannister'): Text(0.05272269248962402, -0.022315357578918338, '10'),
#  ('Brynden-Tully',
#   'Walder-Frey'): Text(0.06284720078110695, -0.06902503967285156, '7'),
#  ('Cersei-Lannister',
#   'Aerys-II-Targaryen'): Text(0.09179045632481575, 0.058892056345939636, '3'),
#  ('Cersei-Lannister',
#   'Alayaya'): Text(0.023781221505487338, 0.14440569281578064, '3'),
#  ('Cersei-Lannister',
#   'Amory-Lorch'): Text(0.01425949577242136, 0.03531389869749546, '4'),
#  ('Cersei-Lannister',
#   'Arya-Stark'): Text(-0.012508019804954529, 0.03122204332612455, '25'),
#  ('Cersei-Lannister',
#   'Arys-Oakheart'): Text(-0.023463115096092224, 0.11685319989919662, '3'),
#  ('Cersei-Lannister',
#   'Aurane-Waters'): Text(0.06829482316970825, 0.03157348185777664, '9'),
#  ('Cersei-Lannister',
#   'Baelor-I-Targaryen'): Text(0.10095379129052162, 0.05782730504870415, '8'),
#  ('Cersei-Lannister',
#   'Balman-Byrch'): Text(0.05322857201099396, 0.11030237376689911, '7'),
#  ('Cersei-Lannister',
#   'Barristan-Selmy'): Text(0.047962915152311325, 0.11711304634809494, '17'),
#  ('Cersei-Lannister',
#   'Benjen-Stark'): Text(-0.014573290944099426, -0.009516667574644089, '3'),
#  ('Cersei-Lannister',
#   'Blue-Bard'): Text(0.11976177617907524, 0.07285058498382568, '7'),
#  ('Cersei-Lannister',
#   'Boros-Blount'): Text(0.04033921845257282, 0.062471337616443634, '23'),
#  ('Cersei-Lannister',
#   'Bran-Stark'): Text(-0.0030168723315000534, -0.01781206950545311, '6'),
#  ('Cersei-Lannister',
#   'Brienne-of-Tarth'): Text(0.07770268991589546, 0.011461703106760979, '8'),
#  ('Cersei-Lannister',
#   'Bronn'): Text(0.048965372145175934, 0.06127520650625229, '23'),
#  ('Cersei-Lannister',
#   'Catelyn-Stark'): Text(0.04665823467075825, 0.0096905417740345, '30'),
#  ('Cersei-Lannister',
#   'Chiswyck'): Text(-0.002422839403152466, 0.05826191045343876, '3'),
#  ('Cersei-Lannister',
#   'Cleos-Frey'): Text(0.05494416132569313, 0.016523978672921658, '6'),
#  ('Cersei-Lannister',
#   'Daenerys-Targaryen'): Text(0.060301732271909714, 0.1531953066587448, '3'),
#  ('Cersei-Lannister',
#   'Doran-Martell'): Text(-0.012376982718706131, 0.12136950343847275, '3'),
#  ('Cersei-Lannister',
#   'Dorcas'): Text(0.06811809912323952, 0.08152731880545616, '18'),
#  ('Cersei-Lannister',
#   'Dunsen'): Text(0.013422641903162003, 0.054567018523812294, '16'),
#  ('Cersei-Lannister',
#   'Eddard-Stark'): Text(0.024188438430428505, 0.0366065027192235, '91'),
#  ('Cersei-Lannister',
#   'Elia-Martell'): Text(0.07555536925792694, 0.09328015148639679, '4'),
#  ('Cersei-Lannister',
#   'Ellaria-Sand'): Text(-0.0024288780987262726, 0.1197948157787323, '4'),
#  ('Cersei-Lannister',
#   'Falyse-Stokeworth'): Text(0.0593838095664978, 0.08747953921556473, '14'),
#  ('Cersei-Lannister',
#   'Garlan-Tyrell'): Text(0.08592991903424263, 0.038794564083218575, '3'),
#  ('Cersei-Lannister',
#   'Garth-Tyrell'): Text(0.182663943618536, 0.09183069318532944, '3'),
#  ('Cersei-Lannister',
#   'Gregor-Clegane'): Text(0.023927730275318027, 0.05477636866271496, '21'),
#  ('Cersei-Lannister',
#   'Gyles-Rosby'): Text(0.0645272471010685, 0.06903260573744774, '24'),
#  ('Cersei-Lannister',
#   'Harys-Swyft'): Text(0.07572229206562042, 0.05026344396173954, '4'),
#  ('Cersei-Lannister',
#   'High-Septon-(Tyrions)'): Text(0.034072015434503555, 0.08991245180368423, '3'),
#  ('Cersei-Lannister',
#   'High-Sparrow'): Text(0.06943367049098015, 0.06949856132268906, '35'),
#  ('Cersei-Lannister',
#   'Ilyn-Payne'): Text(0.03272768948227167, 0.03690325655043125, '34'),
#  ('Cersei-Lannister',
#   'Jacelyn-Bywater'): Text(0.029558269307017326, 0.07037980481982231, '4'),
#  ('Cersei-Lannister',
#   'Jaime-Lannister'): Text(0.06322912871837616, 0.024172419914975762, '130'),
#  ('Cersei-Lannister',
#   'Jalabhar-Xho'): Text(0.13929461315274239, 0.09055139124393463, '3'),
#  ('Cersei-Lannister',
#   'Janos-Slynt'): Text(-0.008945554494857788, 0.02339132083579898, '13'),
#  ('Cersei-Lannister',
#   'Jocelyn-Swyft'): Text(0.07811027020215988, 0.08283496275544167, '13'),
#  ('Cersei-Lannister',
#   'Joffrey-Baratheon'): Text(0.026297891279682517, 0.04348589852452278, '173'),
#  ('Cersei-Lannister',
#   'Jon-Arryn'): Text(0.05761631578207016, 0.04774043895304203, '7'),
#  ('Cersei-Lannister',
#   'Jon-Snow'): Text(-0.0459430031478405, -0.002680540084838867, '7'),
#  ('Cersei-Lannister',
#   'Jory-Cassel'): Text(0.002783576026558876, 0.030954545130953193, '5'),
#  ('Cersei-Lannister',
#   'Kevan-Lannister'): Text(0.06183553859591484, 0.03128071501851082, '24'),
#  ('Cersei-Lannister',
#   'Lancel-Lannister'): Text(0.06791909411549568, 0.04274547006934881, '38'),
#  ('Cersei-Lannister',
#   'Loras-Tyrell'): Text(0.04213769920170307, 0.03738689515739679, '24'),
#  ('Cersei-Lannister',
#   'Lysa-Arryn'): Text(0.0635058768093586, 0.04135270323604345, '9'),
#  ('Cersei-Lannister',
#   'Mace-Tyrell'): Text(0.05131220072507858, 0.04164202883839607, '26'),
#  ('Cersei-Lannister',
#   'Maegor-I-Targaryen'): Text(0.09616046771407127, 0.11075948923826218, '3'),
#  ('Cersei-Lannister',
#   'Maggy'): Text(-0.018379557877779007, 0.1316220611333847, '5'),
#  ('Cersei-Lannister',
#   'Mandon-Moore'): Text(0.03691847808659077, 0.07347384840250015, '4'),
#  ('Cersei-Lannister',
#   'Margaery-Tyrell'): Text(0.05854955315589905, 0.050128646194934845, '79'),
#  ('Cersei-Lannister',
#   'Mark-Mullendore'): Text(0.0037856455892324448, 0.18751098215579987, '3'),
#  ('Cersei-Lannister',
#   'Melara-Hetherspoon'): Text(-0.043204616755247116, 0.11355723440647125, '5'),
#  ('Cersei-Lannister',
#   'Meryn-Trant'): Text(0.025954199489206076, 0.05291513726115227, '46'),
#  ('Cersei-Lannister',
#   'Moelle'): Text(0.1471378616988659, 0.0720192901790142, '4'),
#  ('Cersei-Lannister',
#   'Moon-Boy'): Text(0.0881473757326603, 0.041361406445503235, '5'),
#  ('Cersei-Lannister',
#   'Mordane'): Text(0.007930795662105083, 0.037457847967743874, '3'),
#  ('Cersei-Lannister',
#   'Myrcella-Baratheon'): Text(0.0006164088845252991, 0.08802706748247147, '19'),
#  ('Cersei-Lannister',
#   'Oberyn-Martell'): Text(0.0220868008909747, 0.08576199412345886, '9'),
#  ('Cersei-Lannister',
#   'Olenna-Redwyne'): Text(0.07075872272253036, 0.043703360483050346, '11'),
#  ('Cersei-Lannister',
#   'Orton-Merryweather'): Text(0.06490985304117203, 0.06663842871785164, '9'),
#  ('Cersei-Lannister',
#   'Osfryd-Kettleblack'): Text(0.08913953229784966, 0.06774237006902695, '15'),
#  ('Cersei-Lannister',
#   'Osmund-Kettleblack'): Text(0.050969284027814865, 0.05121568217873573, '37'),
#  ('Cersei-Lannister',
#   'Osney-Kettleblack'): Text(0.06444977596402168, 0.06118515878915787, '30'),
#  ('Cersei-Lannister',
#   'Petyr-Baelish'): Text(0.05892523378133774, 0.05366864427924156, '27'),
#  ('Cersei-Lannister',
#   'Polliver'): Text(0.008613668382167816, 0.048619309440255165, '9'),
#  ('Cersei-Lannister',
#   'Preston-Greenfield'): Text(0.12548309192061424, 0.10291121900081635, '3'),
#  ('Cersei-Lannister',
#   'Pycelle'): Text(0.05682845041155815, 0.050194449722766876, '34'),
#  ('Cersei-Lannister',
#   'Qyburn'): Text(0.06730521470308304, 0.03923509269952774, '30'),
#  ('Cersei-Lannister',
#   'Rafford'): Text(0.01671842811629176, 0.048483144491910934, '16'),
#  ('Cersei-Lannister',
#   'Raynard'): Text(0.22003720328211784, -0.01534254476428032, '3'),
#  ('Cersei-Lannister',
#   'Renly-Baratheon'): Text(0.04965808615088463, 0.027713739458704367, '12'),
#  ('Cersei-Lannister',
#   'Rhaegar-Targaryen'): Text(0.06577833369374275, 0.09182631969451904, '8'),
#  ('Cersei-Lannister',
#   'Robb-Stark'): Text(0.024422624555882066, -0.00659685954451561, '15'),
#  ('Cersei-Lannister',
#   'Robert-Baratheon'): Text(0.033236938528716564, 0.05196996219456196, '134'),
#  ('Cersei-Lannister',
#   'Robert-Strong'): Text(0.10464467480778694, 0.015633966773748398, '4'),
#  ('Cersei-Lannister',
#   'Sandor-Clegane'): Text(0.018392957281321287, 0.04465632699429989, '19'),
#  ('Cersei-Lannister',
#   'Sansa-Stark'): Text(0.034086233004927635, 0.03988292161375284, '95'),
#  ('Cersei-Lannister',
#   'Scolera'): Text(0.1418151520192623, 0.07054978236556053, '5'),
#  ('Cersei-Lannister',
#   'Senelle'): Text(0.08445695042610168, 0.10485625267028809, '9'),
#  ('Cersei-Lannister',
#   'Shae'): Text(0.04485246352851391, 0.07120029628276825, '9'),
#  ('Cersei-Lannister',
#   'Stannis-Baratheon'): Text(0.0075809527188539505, 0.01882136333733797, '42'),
#  ('Cersei-Lannister',
#   'Taena-of-Myr'): Text(0.05649733543395996, 0.06654031574726105, '46'),
#  ('Cersei-Lannister',
#   'Tallad'): Text(0.14653341844677925, 0.07858219742774963, '4'),
#  ('Cersei-Lannister',
#   'Tanda-Stokeworth'): Text(0.04191198945045471, 0.08586129173636436, '3'),
#  ('Cersei-Lannister',
#   'Tickler'): Text(0.01083185151219368, 0.05651109665632248, '11'),
#  ('Cersei-Lannister',
#   'Tommen-Baratheon'): Text(0.040299754589796066, 0.050137532874941826, '111'),
#  ('Cersei-Lannister',
#   'Tyrion-Lannister'): Text(0.043343354016542435, 0.05800010822713375, '209'),
#  ('Cersei-Lannister',
#   'Tywin-Lannister'): Text(0.04753901809453964, 0.030891954200342298, '57'),
#  ('Cersei-Lannister',
#   'Unella'): Text(0.11179129406809807, 0.0717814564704895, '13'),
#  ('Cersei-Lannister',
#   'Varys'): Text(0.04318522475659847, 0.05901500582695007, '53'),
#  ('Cersei-Lannister',
#   'Vayon-Poole'): Text(-0.0007321778684854507, 0.06482700631022453, '4'),
#  ('Cersei-Lannister',
#   'Vylarr'): Text(0.09657752886414528, 0.11389695852994919, '3'),
#  ('Cersei-Lannister',
#   'Walder-Frey'): Text(0.05766352638602257, -0.015817727893590927, '5'),
#  ('Cersei-Lannister',
#   'Willas-Tyrell'): Text(0.07537800818681717, 0.03742950316518545, '5'),
#  ('Gyles-Rosby',
#   'Aurane-Waters'): Text(0.08580483123660088, 0.045860204845666885, '3'),
#  ('Gyles-Rosby',
#   'Boros-Blount'): Text(0.057849226519465446, 0.07675806060433388, '5'),
#  ('Gyles-Rosby',
#   'Harys-Swyft'): Text(0.09323230013251305, 0.06455016694962978, '6'),
#  ('Gyles-Rosby',
#   'Jacelyn-Bywater'): Text(0.04706827737390995, 0.08466652780771255, '4'),
#  ('Gyles-Rosby',
#   'Jalabhar-Xho'): Text(0.156804621219635, 0.10483811423182487, '4'),
#  ('Gyles-Rosby',
#   'Joffrey-Baratheon'): Text(0.04380789934657514, 0.057772621512413025, '4'),
#  ('Gyles-Rosby',
#   'Lollys-Stokeworth'): Text(0.06252128444612026, 0.11147475615143776, '5'),
#  ('Gyles-Rosby',
#   'Mace-Tyrell'): Text(0.0688222087919712, 0.055928751826286316, '3'),
#  ('Gyles-Rosby',
#   'Margaery-Tyrell'): Text(0.07605956122279167, 0.06441536918282509, '5'),
#  ('Gyles-Rosby',
#   'Orton-Merryweather'): Text(0.08241986110806465, 0.08092515170574188, '4'),
#  ('Gyles-Rosby',
#   'Pycelle'): Text(0.07433845847845078, 0.06448117271065712, '12'),
#  ('Gyles-Rosby',
#   'Qyburn'): Text(0.08481522276997566, 0.053521815687417984, '4'),
#  ('Gyles-Rosby',
#   'Sansa-Stark'): Text(0.05159624107182026, 0.054169644601643085, '3'),
#  ('Gyles-Rosby',
#   'Tanda-Stokeworth'): Text(0.059421997517347336, 0.10014801472425461, '5'),
#  ('Gyles-Rosby',
#   'Tommen-Baratheon'): Text(0.05780976265668869, 0.06442425586283207, '4'),
#  ('Gyles-Rosby',
#   'Tyrion-Lannister'): Text(0.06085336208343506, 0.072286831215024, '3'),
#  ('Jaime-Lannister',
#   'Aemon-Targaryen-(Dragonknight)'): Text(0.1925317533314228, -0.09529059915803373, '3'),
#  ('Jaime-Lannister',
#   'Aerys-II-Targaryen'): Text(0.10800234600901604, 0.028318593511357903, '37'),
#  ('Jaime-Lannister',
#   'Amerei-Frey'): Text(0.13712609931826591, -0.006772646680474281, '6'),
#  ('Jaime-Lannister',
#   'Amory-Lorch'): Text(0.030471385456621647, 0.004740435862913728, '3'),
#  ('Jaime-Lannister',
#   'Arya-Stark'): Text(0.003703869879245758, 0.0006485804915428162, '13'),
#  ('Jaime-Lannister',
#   'Balon-Swann'): Text(0.030080574564635754, 0.052863756427541375, '8'),
#  ('Jaime-Lannister',
#   'Barristan-Selmy'): Text(0.06417480483651161, 0.08653958351351321, '8'),
#  ('Jaime-Lannister',
#   'Beric-Dondarrion'): Text(0.010478613898158073, 0.009899366879835725, '7'),
#  ('Jaime-Lannister',
#   'Bonifer-Hasty'): Text(0.18583067134022713, -0.06343134655617177, '4'),
#  ('Jaime-Lannister',
#   'Boros-Blount'): Text(0.05655110813677311, 0.0318978747818619, '9'),
#  ('Jaime-Lannister',
#   'Brienne-of-Tarth'): Text(0.09391457960009575, -0.019111759727820754, '111'),
#  ('Jaime-Lannister',
#   'Catelyn-Stark'): Text(0.06287012435495853, -0.020882921060547233, '59'),
#  ('Jaime-Lannister',
#   'Clement-Piper'): Text(0.17951612547039986, -0.09168167202733457, '3'),
#  ('Jaime-Lannister',
#   'Cleos-Frey'): Text(0.07115605100989342, -0.014049484161660075, '32'),
#  ('Jaime-Lannister',
#   'Daven-Lannister'): Text(0.12126113846898079, -0.03797199740074575, '12'),
#  ('Jaime-Lannister',
#   'Dick-Crabb'): Text(0.14520686492323875, -0.029500987147912383, '3'),
#  ('Jaime-Lannister',
#   'Eddard-Stark'): Text(0.04040032811462879, 0.0060330398846417665, '33'),
#  ('Jaime-Lannister',
#   'Edmure-Tully'): Text(0.07459711283445358, -0.03408472775481641, '35'),
#  ('Jaime-Lannister',
#   'Edwyn-Frey'): Text(0.11351913586258888, -0.06290965690277517, '9'),
#  ('Jaime-Lannister',
#   'Elia-Martell'): Text(0.09176725894212723, 0.06270668865181506, '4'),
#  ('Jaime-Lannister',
#   'Elmar-Frey'): Text(0.0597451813519001, -0.03877899958752096, '6'),
#  ('Jaime-Lannister',
#   'Emmon-Frey'): Text(0.1092568077147007, -0.05098844482563436, '8'),
#  ('Jaime-Lannister',
#   'Galbart-Glover'): Text(0.051595055498182774, -0.07892422913573682, '3'),
#  ('Jaime-Lannister',
#   'Garrett-Paege'): Text(0.22215795889496803, -0.02756230882368982, '3'),
#  ('Jaime-Lannister',
#   'Genna-Lannister'): Text(0.13354435935616493, -0.042385646840557456, '7'),
#  ('Jaime-Lannister',
#   'Gerold-Hightower'): Text(0.16405140236020088, 0.06316042901016772, '4'),
#  ('Jaime-Lannister',
#   'Gregor-Clegane'): Text(0.04013961995951831, 0.024202905828133225, '15'),
#  ('Jaime-Lannister',
#   'Harys-Swyft'): Text(0.09193418174982071, 0.019689981127157807, '3'),
#  ('Jaime-Lannister',
#   'Hoster-Blackwood'): Text(0.19725826755166054, -0.03596209152601659, '4'),
#  ('Jaime-Lannister',
#   'Hoster-Tully'): Text(0.07675906270742416, -0.030262011801823974, '4'),
#  ('Jaime-Lannister',
#   'Hugo-Vance'): Text(0.21295912936329842, -0.05972264497540891, '3'),
#  ('Jaime-Lannister',
#   'Ilyn-Payne'): Text(0.04893957916647196, 0.006329793715849519, '30'),
#  ('Jaime-Lannister',
#   'Joffrey-Baratheon'): Text(0.042509780963882804, 0.012912435689941049, '45'),
#  ('Jaime-Lannister',
#   'Jon-Arryn'): Text(0.07382820546627045, 0.017166976118460298, '5'),
#  ('Jaime-Lannister',
#   'Jon-Snow'): Text(-0.029731113463640213, -0.0332540029194206, '3'),
#  ('Jaime-Lannister',
#   'Jonos-Bracken'): Text(0.14856963977217674, -0.03874635114334524, '9'),
#  ('Jaime-Lannister',
#   'Jory-Cassel'): Text(0.018995465710759163, 0.00038108229637145996, '4'),
#  ('Jaime-Lannister',
#   'Josmyn-Peckledon'): Text(0.13211895897984505, -0.018087680218741298, '17'),
#  ('Jaime-Lannister',
#   'Joy-Hill'): Text(0.18743114545941353, -0.09701530425809324, '3'),
#  ('Jaime-Lannister',
#   'Karyl-Vance'): Text(0.14365355297923088, -0.06944734393619001, '4'),
#  ('Jaime-Lannister',
#   'Kevan-Lannister'): Text(0.07804742828011513, 0.0007072521839290857, '13'),
#  ('Jaime-Lannister',
#   'Lancel-Lannister'): Text(0.08413098379969597, 0.01217200723476708, '22'),
#  ('Jaime-Lannister',
#   'Lem'): Text(-0.025820087641477585, 0.027458727592602372, '6'),
#  ('Jaime-Lannister',
#   'Lewys-Piper'): Text(0.21652281656861305, -0.04114052816294134, '3'),
#  ('Jaime-Lannister',
#   'Loras-Tyrell'): Text(0.05834958888590336, 0.006813432322815061, '37'),
#  ('Jaime-Lannister',
#   'Lyle-Crakehall'): Text(0.10984115675091743, -0.01911005168221891, '9'),
#  ('Jaime-Lannister',
#   'Lysa-Arryn'): Text(0.07971776649355888, 0.01077924040146172, '9'),
#  ('Jaime-Lannister',
#   'Mace-Tyrell'): Text(0.06752409040927887, 0.01106856600381434, '5'),
#  ('Jaime-Lannister',
#   'Mandon-Moore'): Text(0.053130367770791054, 0.04290038556791842, '4'),
#  ('Jaime-Lannister',
#   'Margaery-Tyrell'): Text(0.07476144284009933, 0.019555183360353112, '10'),
#  ('Jaime-Lannister',
#   'Mariya-Darry'): Text(0.032473201397806406, -0.03918485133908689, '6'),
#  ('Jaime-Lannister',
#   'Melara-Hetherspoon'): Text(-0.02699272707104683, 0.08298377157188952, '3'),
#  ('Jaime-Lannister',
#   'Meryn-Trant'): Text(0.04216608917340636, 0.022341674426570535, '9'),
#  ('Jaime-Lannister',
#   'Oberyn-Martell'): Text(0.03829869057517499, 0.05518853128887713, '3'),
#  ('Jaime-Lannister',
#   'Olenna-Redwyne'): Text(0.08697061240673065, 0.013129897648468614, '3'),
#  ('Jaime-Lannister',
#   'Osmund-Kettleblack'): Text(0.06718117371201515, 0.020642219344154, '22'),
#  ('Jaime-Lannister',
#   'Petyr-Baelish'): Text(0.07513712346553802, 0.02309518144465983, '11'),
#  ('Jaime-Lannister',
#   'Pia'): Text(0.13012557849287987, -0.002892420132411644, '10'),
#  ('Jaime-Lannister',
#   'Pycelle'): Text(0.07304034009575844, 0.019620986888185143, '10'),
#  ('Jaime-Lannister',
#   'Qyburn'): Text(0.08351710438728333, 0.008661629864946008, '25'),
#  ('Jaime-Lannister',
#   'Rafford'): Text(0.03293031780049205, 0.0179096816573292, '3'),
#  ('Jaime-Lannister',
#   'Renly-Baratheon'): Text(0.06586997583508492, -0.0028597233758773655, '28'),
#  ('Jaime-Lannister',
#   'Rennifer-Longwaters'): Text(0.2629401721060276, 0.0004758459981530905, '3'),
#  ('Jaime-Lannister',
#   'Rhaegar-Targaryen'): Text(0.08199022337794304, 0.06125285685993731, '7'),
#  ('Jaime-Lannister',
#   'Rickard-Karstark'): Text(0.05475481506437063, -0.05180898471735418, '7'),
#  ('Jaime-Lannister',
#   'Robb-Stark'): Text(0.04063451424008235, -0.03717032237909734, '41'),
#  ('Jaime-Lannister',
#   'Robert-Baratheon'): Text(0.04944882821291685, 0.021396499359980226, '69'),
#  ('Jaime-Lannister',
#   'Robin-Ryger'): Text(0.12865251675248146, -0.036591714015230536, '9'),
#  ('Jaime-Lannister',
#   'Rodrik-Cassel'): Text(0.03518776036798954, -0.04940455569885671, '3'),
#  ('Jaime-Lannister',
#   'Ronnet-Connington'): Text(0.17079836502671242, -0.0052630596328526735, '4'),
#  ('Jaime-Lannister',
#   'Roose-Bolton'): Text(0.045473495963960886, -0.04300451441667974, '17'),
#  ('Jaime-Lannister',
#   'Rorge'): Text(0.042004542192444205, -0.0314867605920881, '9'),
#  ('Jaime-Lannister',
#   'Ryman-Frey'): Text(0.08466105908155441, -0.05771980597637594, '13'),
#  ('Jaime-Lannister',
#   'Sandor-Clegane'): Text(0.034604846965521574, 0.014082864159718156, '21'),
#  ('Jaime-Lannister',
#   'Sansa-Stark'): Text(0.05029812268912792, 0.00930945877917111, '23'),
#  ('Jaime-Lannister',
#   'Shadrich'): Text(0.21227676048874855, -0.03247716440819204, '3'),
#  ('Jaime-Lannister',
#   'Shagwell'): Text(0.11632882431149483, -0.0617075318004936, '4'),
#  ('Jaime-Lannister',
#   'Shitmouth'): Text(0.20529605820775032, -0.07252856134437025, '3'),
#  ('Jaime-Lannister',
#   'Stafford-Lannister'): Text(0.0578888263553381, -0.07584715425036848, '3'),
#  ('Jaime-Lannister',
#   'Stannis-Baratheon'): Text(0.023792842403054237, -0.011752099497243762, '12'),
#  ('Jaime-Lannister',
#   'Sybell-Spicer'): Text(0.11195087805390358, -0.04903149395249784, '4'),
#  ('Jaime-Lannister',
#   'Taena-of-Myr'): Text(0.07270922511816025, 0.035966852912679315, '4'),
#  ('Jaime-Lannister',
#   'Theon-Greyjoy'): Text(0.022837845608592033, -0.09354532300494611, '4'),
#  ('Jaime-Lannister',
#   'Thoros-of-Myr'): Text(-0.002539612352848053, 0.016409687930718064, '6'),
#  ('Jaime-Lannister',
#   'Tommen-Baratheon'): Text(0.05651164427399635, 0.019564070040360093, '36'),
#  ('Jaime-Lannister',
#   'Tyrion-Lannister'): Text(0.05955524370074272, 0.027426645392552018, '113'),
#  ('Jaime-Lannister',
#   'Tysha'): Text(0.09476004540920258, 0.040918985614553094, '3'),
#  ('Jaime-Lannister',
#   'Tytos-Blackwood'): Text(0.11638952419161797, -0.06447021453641355, '6'),
#  ('Jaime-Lannister',
#   'Tywin-Lannister'): Text(0.06375090777873993, 0.0003184913657605648, '51'),
#  ('Jaime-Lannister',
#   'Urswyck'): Text(0.14346320554614067, -0.03773361607454717, '11'),
#  ('Jaime-Lannister',
#   'Vargo-Hoat'): Text(0.06135285831987858, -0.029954069992527366, '22'),
#  ('Jaime-Lannister',
#   'Varys'): Text(0.05939711444079876, 0.02844154299236834, '19'),
#  ('Jaime-Lannister',
#   'Walder-Frey'): Text(0.07387541607022285, -0.04639119072817266, '5'),
#  ('Jaime-Lannister',
#   'Walder-Rivers'): Text(0.10682639852166176, -0.08035265444777906, '4'),
#  ('Jaime-Lannister',
#   'Walton'): Text(0.11764298751950264, -0.04094765125773847, '18'),
#  ('Jaime-Lannister',
#   'Wyl-(guard)'): Text(-0.006743915379047394, 0.044744482496753335, '3'),
#  ('Jaime-Lannister',
#   'Wylis-Manderly'): Text(0.1745351441204548, -0.01742886914871633, '3'),
#  ('Jaime-Lannister',
#   'Zollo'): Text(0.10045547783374786, -0.07622830360196531, '3'),
#  ('Jalabhar-Xho',
#   'Lambert-Turnberry'): Text(0.30574337393045425, 0.1470002382993698, '3'),
#  ('Jalabhar-Xho',
#   'Tallad'): Text(0.23881079256534576, 0.11438770592212677, '3'),
#  ('Joffrey-Baratheon',
#   'Aerys-II-Targaryen'): Text(0.0710711085703224, 0.04763207212090492, '6'),
#  ('Joffrey-Baratheon',
#   'Alliser-Thorne'): Text(-0.051184876123443246, -0.005984051153063774, '4'),
#  ('Joffrey-Baratheon',
#   'Amory-Lorch'): Text(-0.006459851982071996, 0.024053914472460747, '7'),
#  ('Joffrey-Baratheon',
#   'Arya-Stark'): Text(-0.033227367559447885, 0.019962059101089835, '53'),
#  ('Joffrey-Baratheon',
#   'Arys-Oakheart'): Text(-0.04418246285058558, 0.10559321567416191, '6'),
#  ('Joffrey-Baratheon',
#   'Balon-Swann'): Text(-0.006850662874057889, 0.0721772350370884, '11'),
#  ('Joffrey-Baratheon',
#   'Barristan-Selmy'): Text(0.02724356739781797, 0.10585306212306023, '13'),
#  ('Joffrey-Baratheon',
#   'Beric-Dondarrion'): Text(-0.02645262354053557, 0.029212845489382744, '3'),
#  ('Joffrey-Baratheon',
#   'Boros-Blount'): Text(0.019619870698079467, 0.05121135339140892, '14'),
#  ('Joffrey-Baratheon',
#   'Bran-Stark'): Text(-0.02373622008599341, -0.029072053730487823, '6'),
#  ('Joffrey-Baratheon',
#   'Brienne-of-Tarth'): Text(0.056983342161402106, 0.00020171888172626495, '4'),
#  ('Joffrey-Baratheon',
#   'Bronn'): Text(0.028246024390682578, 0.050015222281217575, '12'),
#  ('Joffrey-Baratheon',
#   'Catelyn-Stark'): Text(0.02593888691626489, -0.0015694424510002136, '11'),
#  ('Joffrey-Baratheon',
#   'Chiswyck'): Text(-0.02314218715764582, 0.047001926228404045, '3'),
#  ('Joffrey-Baratheon',
#   'Davos-Seaworth'): Text(-0.0007809621747583151, 0.04193522967398167, '10'),
#  ('Joffrey-Baratheon',
#   'Dontos-Hollard'): Text(0.02945395722053945, 0.027442846447229385, '22'),
#  ('Joffrey-Baratheon',
#   'Dunsen'): Text(-0.007296705851331353, 0.04330703429877758, '9'),
#  ('Joffrey-Baratheon',
#   'Eddard-Stark'): Text(0.003469090675935149, 0.025346518494188786, '41'),
#  ('Joffrey-Baratheon',
#   'Garlan-Tyrell'): Text(0.06521057127974927, 0.02753457985818386, '10'),
#  ('Joffrey-Baratheon',
#   'Gregor-Clegane'): Text(0.003208382520824671, 0.043516384437680244, '12'),
#  ('Joffrey-Baratheon',
#   'Hallyne'): Text(-0.006717916810885072, 0.1112886480987072, '3'),
#  ('Joffrey-Baratheon',
#   'High-Septon-(fat_one)'): Text(0.057300874730572104, 0.007264215499162674, '4'),
#  ('Joffrey-Baratheon',
#   'High-Septon-(Tyrions)'): Text(0.0133526676800102, 0.07865246757864952, '6'),
#  ('Joffrey-Baratheon',
#   'Horas-Redwyne'): Text(-0.19173526973463595, 0.05910728871822357, '3'),
#  ('Joffrey-Baratheon',
#   'Ilyn-Payne'): Text(0.012008341727778316, 0.025643272325396538, '26'),
#  ('Joffrey-Baratheon',
#   'Jacelyn-Bywater'): Text(0.00883892155252397, 0.0591198205947876, '7'),
#  ('Joffrey-Baratheon',
#   'Janos-Slynt'): Text(-0.029664902249351144, 0.012131336610764265, '14'),
#  ('Joffrey-Baratheon',
#   'Jon-Snow'): Text(-0.06666235090233386, -0.013940524309873581, '14'),
#  ('Joffrey-Baratheon',
#   'Kevan-Lannister'): Text(0.041116190841421485, 0.020020730793476105, '11'),
#  ('Joffrey-Baratheon',
#   'Lancel-Lannister'): Text(0.047199746361002326, 0.0314854858443141, '4'),
#  ('Joffrey-Baratheon',
#   'Loras-Tyrell'): Text(0.021418351447209716, 0.02612691093236208, '18'),
#  ('Joffrey-Baratheon',
#   'Mace-Tyrell'): Text(0.030592852970585227, 0.03038204461336136, '17'),
#  ('Joffrey-Baratheon',
#   'Mance-Rayder'): Text(-0.07332430989481509, -0.029480822384357452, '5'),
#  ('Joffrey-Baratheon',
#   'Mandon-Moore'): Text(0.01619913033209741, 0.06221386417746544, '8'),
#  ('Joffrey-Baratheon',
#   'Margaery-Tyrell'): Text(0.03783020540140569, 0.03886866196990013, '56'),
#  ('Joffrey-Baratheon',
#   'Melisandre'): Text(-0.0415278731379658, 0.0095443744212389, '4'),
#  ('Joffrey-Baratheon',
#   'Meryn-Trant'): Text(0.00523485173471272, 0.041655153036117554, '34'),
#  ('Joffrey-Baratheon',
#   'Mordane'): Text(-0.012788552092388272, 0.02619786374270916, '9'),
#  ('Joffrey-Baratheon',
#   'Mycah'): Text(-0.019421594450250268, 0.02836915571242571, '17'),
#  ('Joffrey-Baratheon',
#   'Myrcella-Baratheon'): Text(-0.020102938869968057, 0.07676708325743675, '30'),
#  ('Joffrey-Baratheon',
#   'Oberyn-Martell'): Text(0.0013674531364813447, 0.07450200989842415, '8'),
#  ('Joffrey-Baratheon',
#   'Olenna-Redwyne'): Text(0.05003937496803701, 0.03244337625801563, '3'),
#  ('Joffrey-Baratheon',
#   'Osmund-Kettleblack'): Text(0.03024993627332151, 0.03995569795370102, '18'),
#  ('Joffrey-Baratheon',
#   'Paxter-Redwyne'): Text(0.01897814846597612, -0.0022567585110664368, '5'),
#  ('Joffrey-Baratheon',
#   'Petyr-Baelish'): Text(0.03820588602684438, 0.04240866005420685, '39'),
#  ('Joffrey-Baratheon',
#   'Polliver'): Text(-0.01210567937232554, 0.03735932521522045, '9'),
#  ('Joffrey-Baratheon',
#   'Pycelle'): Text(0.036109102657064795, 0.03893446549773216, '19'),
#  ('Joffrey-Baratheon',
#   'Qyburn'): Text(0.04658586694858968, 0.027975108474493027, '3'),
#  ('Joffrey-Baratheon',
#   'Rafford'): Text(-0.004000919638201594, 0.03722316026687622, '9'),
#  ('Joffrey-Baratheon',
#   'Renly-Baratheon'): Text(0.028938738396391273, 0.016453755233669654, '25'),
#  ('Joffrey-Baratheon',
#   'Robb-Stark'): Text(0.0037032768013887107, -0.017856843769550323, '49'),
#  ('Joffrey-Baratheon',
#   'Robert-Baratheon'): Text(0.012517590774223208, 0.040709977969527245, '64'),
#  ('Joffrey-Baratheon',
#   'Rodrik-Cassel'): Text(-0.0017434770707041025, -0.030091077089309692, '9'),
#  ('Joffrey-Baratheon',
#   'Sandor-Clegane'): Text(-0.0023263904731720686, 0.033396342769265175, '71'),
#  ('Joffrey-Baratheon',
#   'Sansa-Stark'): Text(0.01336688525043428, 0.028622937388718128, '222'),
#  ('Joffrey-Baratheon',
#   'Selyse-Florent'): Text(-0.06996242166496813, 0.018962153932079673, '3'),
#  ('Joffrey-Baratheon',
#   'Shae'): Text(0.024133115774020553, 0.059940312057733536, '3'),
#  ('Joffrey-Baratheon',
#   'Shireen-Baratheon'): Text(-0.05200844840146601, 0.05342908203601837, '3'),
#  ('Joffrey-Baratheon',
#   'Stannis-Baratheon'): Text(-0.013138395035639405, 0.007561379112303257, '45'),
#  ('Joffrey-Baratheon',
#   'Tickler'): Text(-0.009887496242299676, 0.045251112431287766, '10'),
#  ('Joffrey-Baratheon',
#   'Tommen-Baratheon'): Text(0.01958040683530271, 0.03887754864990711, '77'),
#  ('Joffrey-Baratheon',
#   'Tyrion-Lannister'): Text(0.02262400626204908, 0.04674012400209904, '219'),
#  ('Joffrey-Baratheon',
#   'Tywin-Lannister'): Text(0.026819670340046287, 0.019631969975307584, '37'),
#  ('Joffrey-Baratheon',
#   'Varys'): Text(0.022465877002105117, 0.04775502160191536, '37'),
#  ('Joffrey-Baratheon',
#   'Yoren'): Text(-0.04467710689641535, 0.020944465417414904, '3'),
#  ('Kevan-Lannister',
#   'High-Sparrow'): Text(0.08425197005271912, 0.04603339359164238, '5'),
#  ('Kevan-Lannister',
#   'Lancel-Lannister'): Text(0.08273739367723465, 0.019280302338302135, '17'),
#  ('Kevan-Lannister',
#   'Mace-Tyrell'): Text(0.06613050028681755, 0.018176861107349396, '5'),
#  ('Kevan-Lannister',
#   'Pycelle'): Text(0.07164674997329712, 0.0267292819917202, '8'),
#  ('Kevan-Lannister',
#   'Randyll-Tarly'): Text(0.06012760475277901, -0.041438695043325424, '6'),
#  ('Kevan-Lannister',
#   'Ronnet-Connington'): Text(0.1694047749042511, 0.0018452354706823826, '3'),
#  ('Kevan-Lannister',
#   'Sansa-Stark'): Text(0.0489045325666666, 0.016417753882706165, '5'),
#  ('Kevan-Lannister',
#   'Stannis-Baratheon'): Text(0.02239925228059292, -0.004643804393708706, '3'),
#  ('Kevan-Lannister',
#   'Tommen-Baratheon'): Text(0.055118054151535034, 0.02667236514389515, '20'),
#  ('Kevan-Lannister',
#   'Tyrion-Lannister'): Text(0.0581616535782814, 0.034534940496087074, '30'),
#  ('Kevan-Lannister',
#   'Tywin-Lannister'): Text(0.06235731765627861, 0.007426786469295621, '32'),
#  ('Kevan-Lannister',
#   'Varys'): Text(0.05800352431833744, 0.0355498380959034, '8'),
#  ('Kevan-Lannister',
#   'Willem-Lannister'): Text(0.1585933417081833, -0.09497976675629616, '3'),
#  ('Lyle-Crakehall',
#   'Amerei-Frey'): Text(0.1675262376666069, -0.01948165544308722, '4'),
#  ('Lyle-Crakehall',
#   'Ilyn-Payne'): Text(0.07933971751481295, -0.00637921504676342, '6'),
#  ('Oberyn-Martell',
#   'Amory-Lorch'): Text(-0.010670942370779812, 0.06633001007139683, '6'),
#  ('Oberyn-Martell',
#   'Anders-Yronwood'): Text(-0.039939655107446015, 0.24554531276226044, '3'),
#  ('Oberyn-Martell',
#   'Areo-Hotah'): Text(-0.05661344726104289, 0.1684461161494255, '3'),
#  ('Oberyn-Martell',
#   'Arianne-Martell'): Text(-0.07908754993695766, 0.19250978529453278, '3'),
#  ('Oberyn-Martell',
#   'Bronn'): Text(0.02403493400197476, 0.09229131788015366, '4'),
#  ('Oberyn-Martell',
#   'Daemon-Sand'): Text(-0.06206225056666881, 0.222069650888443, '3'),
#  ('Oberyn-Martell',
#   'Doran-Martell'): Text(-0.0373074208619073, 0.15238561481237411, '14'),
#  ('Oberyn-Martell',
#   'Elia-Martell'): Text(0.05062493111472577, 0.12429626286029816, '9'),
#  ('Oberyn-Martell',
#   'Ellaria-Sand'): Text(-0.027359316241927445, 0.15081092715263367, '7'),
#  ('Oberyn-Martell',
#   'Gregor-Clegane'): Text(-0.0010027078678831458, 0.08579248003661633, '42'),
#  ('Oberyn-Martell',
#   'Mace-Tyrell'): Text(0.02638176258187741, 0.07265814021229744, '15'),
#  ('Oberyn-Martell',
#   'Sansa-Stark'): Text(0.009155794861726463, 0.07089903298765421, '3'),
#  ('Oberyn-Martell',
#   'Tyene-Sand'): Text(-0.10154317517299205, 0.2088834047317505, '3'),
#  ('Oberyn-Martell',
#   'Tyrion-Lannister'): Text(0.018412915873341262, 0.08901621960103512, '41'),
#  ('Oberyn-Martell',
#   'Tywin-Lannister'): Text(0.02260857995133847, 0.061908065574243665, '9'),
#  ('Oberyn-Martell',
#   'Viserys-Targaryen'): Text(0.03634308080654591, 0.15592005103826523, '4'),
#  ('Tyrion-Lannister',
#   'Aegon-I-Targaryen'): Text(-0.010481961071491241, 0.136283366009593, '3'),
#  ('Tyrion-Lannister',
#   'Aegon-Targaryen-(son-of-Rhaegar)'): Text(0.09502626955509186, 0.09667049162089825, '23'),
#  ('Tyrion-Lannister',
#   'Aerys-II-Targaryen'): Text(0.08811657130718231, 0.06214628182351589, '9'),
#  ('Tyrion-Lannister',
#   'Alayaya'): Text(0.0201073364878539, 0.1476599182933569, '7'),
#  ('Tyrion-Lannister',
#   'Allar-Deem'): Text(-0.035065289586782455, 0.10655183903872967, '4'),
#  ('Tyrion-Lannister',
#   'Alliser-Thorne'): Text(-0.03413941338658333, 0.008530158549547195, '15'),
#  ('Tyrion-Lannister',
#   'Arya-Stark'): Text(-0.016181904822587967, 0.034476268803700805, '11'),
#  ('Tyrion-Lannister',
#   'Baelor-I-Targaryen'): Text(0.09727990627288818, 0.0610815305262804, '3'),
#  ('Tyrion-Lannister',
#   'Ballabar'): Text(0.12244733422994614, 0.07324508391320705, '16'),
#  ('Tyrion-Lannister',
#   'Balon-Swann'): Text(0.010194799862802029, 0.08669144473969936, '15'),
#  ('Tyrion-Lannister',
#   'Barristan-Selmy'): Text(0.04428903013467789, 0.1203672718256712, '3'),
#  ('Tyrion-Lannister',
#   'Ben-Plumm'): Text(0.04897184111177921, 0.1580954845994711, '4'),
#  ('Tyrion-Lannister',
#   'Benerro'): Text(0.09790066629648209, 0.0657843928784132, '7'),
#  ('Tyrion-Lannister',
#   'Benjen-Stark'): Text(-0.018247175961732864, -0.006262442097067833, '8'),
#  ('Tyrion-Lannister',
#   'Boros-Blount'): Text(0.036665333434939384, 0.06572556309401989, '14'),
#  ('Tyrion-Lannister',
#   'Bran-Stark'): Text(-0.0066907573491334915, -0.014557844027876854, '31'),
#  ('Tyrion-Lannister',
#   'Brienne-of-Tarth'): Text(0.07402880489826202, 0.014715928584337234, '7'),
#  ('Tyrion-Lannister',
#   'Bronn'): Text(0.045291487127542496, 0.06452943198382854, '137'),
#  ('Tyrion-Lannister',
#   'Catelyn-Stark'): Text(0.04298434965312481, 0.012944767251610756, '69'),
#  ('Tyrion-Lannister',
#   'Chataya'): Text(0.11496558785438538, 0.06856578402221203, '10'),
#  ('Tyrion-Lannister',
#   'Chella'): Text(0.033185807056725025, 0.11393232457339764, '8'),
#  ('Tyrion-Lannister',
#   'Chiggen'): Text(0.023142004618421197, 0.10655675642192364, '5'),
#  ('Tyrion-Lannister',
#   'Cleos-Frey'): Text(0.05127027630805969, 0.019778204150497913, '13'),
#  ('Tyrion-Lannister',
#   'Conn'): Text(0.13271939754486084, 0.13554353080689907, '6'),
#  ('Tyrion-Lannister',
#   'Cortnay-Penrose'): Text(0.03705559857189655, 0.021492493338882923, '3'),
#  ('Tyrion-Lannister',
#   'Daenerys-Targaryen'): Text(0.056627847254276276, 0.15644953213632107, '17'),
#  ('Tyrion-Lannister',
#   'Dontos-Hollard'): Text(0.04649941995739937, 0.041957056149840355, '14'),
#  ('Tyrion-Lannister',
#   'Doran-Martell'): Text(-0.01605086773633957, 0.124623728916049, '13'),
#  ('Tyrion-Lannister',
#   'Eddard-Stark'): Text(0.020514553412795067, 0.039860728196799755, '40'),
#  ('Tyrion-Lannister',
#   'Elia-Martell'): Text(0.0718814842402935, 0.09653437696397305, '6'),
#  ('Tyrion-Lannister',
#   'Ellaria-Sand'): Text(-0.006102763116359711, 0.12304904125630856, '4'),
#  ('Tyrion-Lannister',
#   'Galyeon-of-Cuy'): Text(-0.011761579662561417, 0.19051826559007168, '3'),
#  ('Tyrion-Lannister',
#   'Garlan-Tyrell'): Text(0.08225603401660919, 0.04204878956079483, '11'),
#  ('Tyrion-Lannister',
#   'Gregor-Clegane'): Text(0.02025384525768459, 0.058030594140291214, '30'),
#  ('Tyrion-Lannister',
#   'Gunthor-son-of-Gurn'): Text(0.01898906222777441, 0.1390563677996397, '7'),
#  ('Tyrion-Lannister',
#   'Haldon'): Text(0.06895755231380463, 0.08843524195253849, '54'),
#  ('Tyrion-Lannister',
#   'Hallyne'): Text(0.010327545925974846, 0.12580285780131817, '5'),
#  ('Tyrion-Lannister',
#   'High-Septon-(fat_one)'): Text(0.07434633746743202, 0.021778425201773643, '4'),
#  ('Tyrion-Lannister',
#   'High-Septon-(Tyrions)'): Text(0.030398130416870117, 0.09316667728126049, '12'),
#  ('Tyrion-Lannister',
#   'Illyrio-Mopatis'): Text(0.055929891765117645, 0.12118339352309704, '30'),
#  ('Tyrion-Lannister',
#   'Ilyn-Payne'): Text(0.029053804464638233, 0.04015748202800751, '6'),
#  ('Tyrion-Lannister',
#   'Jacelyn-Bywater'): Text(0.025884384289383888, 0.07363403029739857, '16'),
#  ('Tyrion-Lannister',
#   'Janos-Slynt'): Text(-0.012619439512491226, 0.026645546313375235, '31'),
#  ('Tyrion-Lannister',
#   'Jeor-Mormont'): Text(-0.043972842395305634, -0.007156966254115105, '27'),
#  ('Tyrion-Lannister',
#   'Jon-Arryn'): Text(0.05394243076443672, 0.050994664430618286, '8'),
#  ('Tyrion-Lannister',
#   'Jon-Connington'): Text(0.1010582372546196, 0.08366716839373112, '37'),
#  ('Tyrion-Lannister',
#   'Jon-Snow'): Text(-0.04961688816547394, 0.0005736853927373886, '56'),
#  ('Tyrion-Lannister',
#   'Jorah-Mormont'): Text(0.055551063269376755, 0.13626212440431118, '27'),
#  ('Tyrion-Lannister',
#   'Jyck'): Text(0.01021751668304205, 0.15318883769214153, '6'),
#  ('Tyrion-Lannister',
#   'Kasporio'): Text(0.021999327465891838, 0.1809182669967413, '3'),
#  ('Tyrion-Lannister',
#   'Kurleket'): Text(0.14880204945802689, 0.0708967987447977, '5'),
#  ('Tyrion-Lannister',
#   'Lancel-Lannister'): Text(0.06424520909786224, 0.04599969554692507, '18'),
#  ('Tyrion-Lannister',
#   'Lemore'): Text(0.08580332249403, 0.08667768351733685, '16'),
#  ('Tyrion-Lannister',
#   'Leo-Lefford'): Text(0.0028573088347911835, 0.1715876068919897, '4'),
#  ('Tyrion-Lannister',
#   'Lollys-Stokeworth'): Text(0.0413373913615942, 0.10044225864112377, '8'),
#  ('Tyrion-Lannister',
#   'Loras-Tyrell'): Text(0.038463814184069633, 0.04064112063497305, '21'),
#  ('Tyrion-Lannister',
#   'Luwin'): Text(0.0010669399052858353, -0.015560371801257133, '10'),
#  ('Tyrion-Lannister',
#   'Lysa-Arryn'): Text(0.05983199179172516, 0.04460692871361971, '36'),
#  ('Tyrion-Lannister',
#   'Mace-Tyrell'): Text(0.047638315707445145, 0.04489625431597233, '18'),
#  ('Tyrion-Lannister',
#   'Mandon-Moore'): Text(0.03324459306895733, 0.07672807388007641, '19'),
#  ('Tyrion-Lannister',
#   'Margaery-Tyrell'): Text(0.05487566813826561, 0.0533828716725111, '10'),
#  ('Tyrion-Lannister',
#   'Marillion'): Text(0.049976348876953125, 0.030786275819991715, '10'),
#  ('Tyrion-Lannister',
#   'Meryn-Trant'): Text(0.022280314471572638, 0.05616936273872852, '12'),
#  ('Tyrion-Lannister',
#   'Moqorro'): Text(0.08416019380092621, -0.030241208150982857, '7'),
#  ('Tyrion-Lannister',
#   'Mord'): Text(0.04708627611398697, 0.10342237912118435, '20'),
#  ('Tyrion-Lannister',
#   'Morgo'): Text(0.16410129517316818, 0.0715839546173811, '4'),
#  ('Tyrion-Lannister',
#   'Morrec'): Text(0.013727483805269003, 0.16031940840184689, '5'),
#  ('Tyrion-Lannister',
#   'Myrcella-Baratheon'): Text(-0.003057476133108139, 0.09128129296004772, '21'),
#  ('Tyrion-Lannister',
#   'Nurse'): Text(0.06543555483222008, 0.12449881993234158, '8'),
#  ('Tyrion-Lannister',
#   'Olenna-Redwyne'): Text(0.06708483770489693, 0.0469575859606266, '3'),
#  ('Tyrion-Lannister',
#   'Osmund-Kettleblack'): Text(0.04729539901018143, 0.05446990765631199, '18'),
#  ('Tyrion-Lannister',
#   'Paxter-Redwyne'): Text(0.03602361120283604, 0.012257451191544533, '4'),
#  ('Tyrion-Lannister',
#   'Penny'): Text(0.04766574874520302, 0.09682643227279186, '59'),
#  ('Tyrion-Lannister',
#   'Petyr-Baelish'): Text(0.0552513487637043, 0.05692286975681782, '71'),
#  ('Tyrion-Lannister',
#   'Pia'): Text(0.11023980379104614, 0.030935268179746345, '3'),
#  ('Tyrion-Lannister',
#   'Podrick-Payne'): Text(0.08175694942474365, 0.03486386779695749, '40'),
#  ('Tyrion-Lannister',
#   'Preston-Greenfield'): Text(0.1218092069029808, 0.1061654444783926, '3'),
#  ('Tyrion-Lannister',
#   'Pycelle'): Text(0.05315456539392471, 0.05344867520034313, '33'),
#  ('Tyrion-Lannister',
#   'Qavo-Nogarys'): Text(0.08299067616462708, 0.13397194258868694, '6'),
#  ('Tyrion-Lannister',
#   'Renly-Baratheon'): Text(0.04598420113325119, 0.030967964936280623, '23'),
#  ('Tyrion-Lannister',
#   'Rickon-Stark'): Text(0.0007731243968009949, -0.00655454583466053, '4'),
#  ('Tyrion-Lannister',
#   'Robb-Stark'): Text(0.02074873953824863, -0.003342634066939354, '44'),
#  ('Tyrion-Lannister',
#   'Robert-Arryn'): Text(0.08563457429409027, 0.08778262697160244, '9'),
#  ('Tyrion-Lannister',
#   'Robert-Baratheon'): Text(0.029563053511083126, 0.055224187672138214, '42'),
#  ('Tyrion-Lannister',
#   'Rodrik-Cassel'): Text(0.015301985666155815, -0.015576867386698723, '10'),
#  ('Tyrion-Lannister',
#   'Rolly-Duckfield'): Text(0.07541140913963318, 0.09417296014726162, '20'),
#  ('Tyrion-Lannister',
#   'Roose-Bolton'): Text(0.02558772126212716, -0.009176826104521751, '6'),
#  ('Tyrion-Lannister',
#   'Sandor-Clegane'): Text(0.014719072263687849, 0.047910552471876144, '25'),
#  ('Tyrion-Lannister',
#   'Sansa-Stark'): Text(0.030412347987294197, 0.0431371470913291, '118'),
#  ('Tyrion-Lannister',
#   'Scar'): Text(0.08372846245765686, 0.12514068000018597, '8'),
#  ('Tyrion-Lannister',
#   'Shae'): Text(0.04117857851088047, 0.0744545217603445, '68'),
#  ('Tyrion-Lannister',
#   'Shagga'): Text(0.09376784414052963, 0.10647067241370678, '32'),
#  ('Tyrion-Lannister',
#   'Shrouded-Lord'): Text(0.12418365478515625, 0.14951184950768948, '4'),
#  ('Tyrion-Lannister',
#   'Stannis-Baratheon'): Text(0.003907067701220512, 0.022075588814914227, '52'),
#  ('Tyrion-Lannister',
#   'Sweets'): Text(0.07246328145265579, 0.1280540805310011, '7'),
#  ('Tyrion-Lannister',
#   'Symon-Silver-Tongue'): Text(0.0363075602799654, 0.12642398290336132, '7'),
#  ('Tyrion-Lannister',
#   'Taena-of-Myr'): Text(0.05282345041632652, 0.0697945412248373, '3'),
#  ('Tyrion-Lannister',
#   'Tanda-Stokeworth'): Text(0.038238104432821274, 0.08911551721394062, '9'),
#  ('Tyrion-Lannister',
#   'Theon-Greyjoy'): Text(0.0029520709067583084, -0.059717634692788124, '3'),
#  ('Tyrion-Lannister',
#   'Timett'): Text(0.06679869815707207, 0.10169234685599804, '13'),
#  ('Tyrion-Lannister',
#   'Tommen-Baratheon'): Text(0.03662586957216263, 0.05339175835251808, '26'),
#  ('Tyrion-Lannister',
#   'Tybero-Istarion'): Text(0.03876630961894989, 0.1430044900625944, '8'),
#  ('Tyrion-Lannister',
#   'Tysha'): Text(0.07487427070736885, 0.07474667392671108, '11'),
#  ('Tyrion-Lannister',
#   'Tywin-Lannister'): Text(0.043865133076906204, 0.03414617967791855, '117'),
#  ('Tyrion-Lannister',
#   'Vardis-Egen'): Text(0.08581116050481796, 0.05298148840665817, '9'),
#  ('Tyrion-Lannister',
#   'Varys'): Text(0.039511339738965034, 0.06226923130452633, '107'),
#  ('Tyrion-Lannister',
#   'Viserys-Targaryen'): Text(0.05759963393211365, 0.12815816514194012, '4'),
#  ('Tyrion-Lannister',
#   'Vylarr'): Text(0.09290364384651184, 0.11715118400752544, '6'),
#  ('Tyrion-Lannister',
#   'Willas-Tyrell'): Text(0.07170412316918373, 0.04068372864276171, '5'),
#  ('Tyrion-Lannister',
#   'Willis-Wode'): Text(0.024811611976474524, 0.026603393722325563, '4'),
#  ('Tyrion-Lannister',
#   'Yandry'): Text(0.08753705024719238, 0.08940712176263332, '15'),
#  ('Tyrion-Lannister',
#   'Yezzan-zo-Qaggaz'): Text(0.06083649769425392, 0.10825475864112377, '17'),
#  ('Tyrion-Lannister',
#   'Yoren'): Text(-0.027631644159555435, 0.03545867512002587, '10'),
#  ('Tyrion-Lannister',
#   'Ysilla'): Text(0.09197378158569336, 0.09740198962390423, '11'),
#  ('Tywin-Lannister',
#   'Aegon-Targaryen-(son-of-Rhaegar)'): Text(0.09922193363308907, 0.0695623375941068, '3'),
#  ('Tywin-Lannister',
#   'Aerys-II-Targaryen'): Text(0.09231223538517952, 0.03503812779672444, '26'),
#  ('Tywin-Lannister',
#   'Amory-Lorch'): Text(0.01478127483278513, 0.011459970148280263, '8'),
#  ('Tywin-Lannister',
#   'Arya-Stark'): Text(-0.01198624074459076, 0.007368114776909351, '13'),
#  ('Tywin-Lannister',
#   'Balon-Greyjoy'): Text(0.042738087475299835, -0.09023333410732448, '4'),
#  ('Tywin-Lannister',
#   'Brienne-of-Tarth'): Text(0.07822446897625923, -0.012392225442454219, '3'),
#  ('Tywin-Lannister',
#   'Bronn'): Text(0.0494871512055397, 0.03742127795703709, '7'),
#  ('Tywin-Lannister',
#   'Catelyn-Stark'): Text(0.04718001373112202, -0.014163386775180697, '21'),
#  ('Tywin-Lannister',
#   'Doran-Martell'): Text(-0.011855203658342361, 0.09751557488925755, '4'),
#  ('Tywin-Lannister',
#   'Eddard-Stark'): Text(0.024710217490792274, 0.012752574170008302, '18'),
#  ('Tywin-Lannister',
#   'Edmure-Tully'): Text(0.058907002210617065, -0.027365193469449878, '11'),
#  ('Tywin-Lannister',
#   'Elia-Martell'): Text(0.07607714831829071, 0.06942622293718159, '3'),
#  ('Tywin-Lannister',
#   'Elmar-Frey'): Text(0.04405507072806358, -0.03205946530215442, '3'),
#  ('Tywin-Lannister',
#   'Emmon-Frey'): Text(0.09356669709086418, -0.044268910540267825, '3'),
#  ('Tywin-Lannister',
#   'Genna-Lannister'): Text(0.11785424873232841, -0.03566611255519092, '3'),
#  ('Tywin-Lannister',
#   'Gregor-Clegane'): Text(0.024449509335681796, 0.03092244011349976, '20'),
#  ('Tywin-Lannister',
#   'Joanna-Lannister'): Text(0.1748359017074108, -0.004061710787937045, '4'),
#  ('Tywin-Lannister',
#   'Jon-Connington'): Text(0.1052539013326168, 0.056559014366939664, '4'),
#  ('Tywin-Lannister',
#   'Jon-Umber-(Greatjon)'): Text(0.04074852913618088, -0.05986701021902263, '3'),
#  ('Tywin-Lannister',
#   'Lysa-Arryn'): Text(0.06402765586972237, 0.017498774686828256, '4'),
#  ('Tywin-Lannister',
#   'Mace-Tyrell'): Text(0.05183397978544235, 0.017788100289180875, '14'),
#  ('Tywin-Lannister',
#   'Marq-Piper'): Text(0.06995289772748947, -0.026834093732759356, '3'),
#  ('Tywin-Lannister',
#   'Martyn-Lannister'): Text(0.1624879650771618, -0.07484631310217083, '3'),
#  ('Tywin-Lannister',
#   'Petyr-Baelish'): Text(0.05944701284170151, 0.029814715730026364, '5'),
#  ('Tywin-Lannister',
#   'Podrick-Payne'): Text(0.08595261350274086, 0.0077557137701660395, '4'),
#  ('Tywin-Lannister',
#   'Pycelle'): Text(0.05735022947192192, 0.02634052117355168, '13'),
#  ('Tywin-Lannister',
#   'Renly-Baratheon'): Text(0.0501798652112484, 0.0038598109094891697, '3'),
#  ('Tywin-Lannister',
#   'Rhaegar-Targaryen'): Text(0.06630011275410652, 0.06797239114530385, '4'),
#  ('Tywin-Lannister',
#   'Robb-Stark'): Text(0.024944403616245836, -0.030450788093730807, '30'),
#  ('Tywin-Lannister',
#   'Robert-Baratheon'): Text(0.033758717589080334, 0.02811603364534676, '29'),
#  ('Tywin-Lannister',
#   'Roose-Bolton'): Text(0.02978338534012437, -0.036284980131313205, '13'),
#  ('Tywin-Lannister',
#   'Sansa-Stark'): Text(0.034608012065291405, 0.016028993064537644, '6'),
#  ('Tywin-Lannister',
#   'Stannis-Baratheon'): Text(0.00810273177921772, -0.005032565211877227, '30'),
#  ('Tywin-Lannister',
#   'Theon-Greyjoy'): Text(0.007147734984755516, -0.08682578871957958, '3'),
#  ('Tywin-Lannister',
#   'Tommen-Baratheon'): Text(0.040821533650159836, 0.02628360432572663, '11'),
#  ('Tywin-Lannister',
#   'Vargo-Hoat'): Text(0.04566274769604206, -0.02323453570716083, '4'),
#  ('Tywin-Lannister',
#   'Varys'): Text(0.04370700381696224, 0.035161077277734876, '9'),
#  ('Tywin-Lannister',
#   'Walder-Frey'): Text(0.05818530544638634, -0.039671656442806125, '12'),
#  ('Tywin-Lannister',
#   'Weese'): Text(-0.014221787452697754, 0.01982906204648316, '7'),
#  ('Tywin-Lannister',
#   'Wylis-Manderly'): Text(0.15884503349661827, -0.010709334863349795, '3'),
#  ('Varys',
#   'Barristan-Selmy'): Text(0.044130900874733925, 0.12138216942548752, '15'),
#  ('Varys', 'Bronn'): Text(0.045133357867598534, 0.06554432958364487, '12'),
#  ('Varys',
#   'Catelyn-Stark'): Text(0.04282622039318085, 0.013959664851427078, '10'),
#  ('Varys', 'Chella'): Text(0.03302767779678106, 0.11494722217321396, '4'),
#  ('Varys',
#   'Cortnay-Penrose'): Text(0.03689746931195259, 0.022507390938699245, '3'),
#  ('Varys',
#   'Daenerys-Targaryen'): Text(0.056469717994332314, 0.1574644297361374, '8'),
#  ('Varys',
#   'Doran-Martell'): Text(-0.01620899699628353, 0.12563862651586533, '4'),
#  ('Varys',
#   'Eddard-Stark'): Text(0.020356424152851105, 0.04087562579661608, '64'),
#  ('Varys', 'Ilyn-Payne'): Text(0.02889567520469427, 0.04117237962782383, '5'),
#  ('Varys',
#   'Jacelyn-Bywater'): Text(0.025726255029439926, 0.07464892789721489, '4'),
#  ('Varys',
#   'Janos-Slynt'): Text(-0.012777568772435188, 0.027660443913191557, '7'),
#  ('Varys', 'Jon-Arryn'): Text(0.05378430150449276, 0.05200956203043461, '5'),
#  ('Varys',
# ...
#  ('Stannis-Baratheon',
#   'Cortnay-Penrose'): Text(0.0012931972742080688, -0.017686251550912857, '18'),
#  ('Stannis-Baratheon',
#   'Cotter-Pyke'): Text(-0.09500649012625217, -0.05138219799846411, '5'),
#  ('Stannis-Baratheon',
#   'Cressen'): Text(-0.04813036136329174, 0.010865959338843822, '21'),
#  ('Stannis-Baratheon',
#   'Dalla'): Text(-0.09206713177263737, -0.039579627104103565, '5'),
#  ('Stannis-Baratheon',
#   'Davos-Seaworth'): Text(-0.01949790073558688, 0.017270694486796856, '131'),
#  ('Stannis-Baratheon',
#   'Devan-Seaworth'): Text(-0.046420082449913025, -0.011088526574894786, '31'),
#  ('Stannis-Baratheon',
#   'Donal-Noye'): Text(-0.10817147232592106, -0.03398208227008581, '4'),
#  ('Stannis-Baratheon',
#   'Dontos-Hollard'): Text(0.010737018659710884, 0.0027783112600445747, '3'),
#  ('Stannis-Baratheon',
#   'Edric-Storm'): Text(-0.015952821646351367, 0.05469459015876055, '6'),
#  ('Stannis-Baratheon',
#   'Godry-Farring'): Text(-0.0501971822232008, -0.07857583742588758, '9'),
#  ('Stannis-Baratheon',
#   'Harys-Swyft'): Text(0.0362860057502985, 0.014338924549520016, '3'),
#  ('Stannis-Baratheon',
#   'Janos-Slynt'): Text(-0.04838184081017971, -0.012533198576420546, '4'),
#  ('Stannis-Baratheon',
#   'Jon-Arryn'): Text(0.018180029466748238, 0.011815919540822506, '13'),
#  ('Stannis-Baratheon',
#   'Jon-Snow'): Text(-0.08537928946316242, -0.03860505949705839, '91'),
#  ('Stannis-Baratheon',
#   'Jory-Cassel'): Text(-0.036652710288763046, -0.004969974281266332, '3'),
#  ('Stannis-Baratheon',
#   'Justin-Massey'): Text(-0.024173990823328495, -0.10199703555554152, '10'),
#  ('Stannis-Baratheon',
#   'Khorane-Sathmantes'): Text(-0.07554247044026852, 0.05120226088911295, '3'),
#  ('Stannis-Baratheon',
#   'Loras-Tyrell'): Text(0.0027014128863811493, 0.001462375745177269, '4'),
#  ('Stannis-Baratheon',
#   'Lyanna-Mormont'): Text(-0.14372787810862064, 0.07117238361388445, '3'),
#  ('Stannis-Baratheon',
#   'Lysa-Arryn'): Text(0.024069590494036674, 0.005428183823823929, '4'),
#  ('Stannis-Baratheon',
#   'Mace-Tyrell'): Text(0.01187591440975666, 0.005717509426176548, '12'),
#  ('Stannis-Baratheon',
#   'Mance-Rayder'): Text(-0.09204124845564365, -0.05414535757154226, '16'),
#  ('Stannis-Baratheon',
#   'Marlon-Manderly'): Text(-0.06552051939070225, 0.06496770400553942, '3'),
#  ('Stannis-Baratheon',
#   'Marya-Seaworth'): Text(-0.1295828763395548, 0.07025450933724642, '3'),
#  ('Stannis-Baratheon',
#   'Mathis-Rowan'): Text(0.05969546549022198, -0.02750051487237215, '3'),
#  ('Stannis-Baratheon',
#   'Melisandre'): Text(-0.060244811698794365, -0.015120160765945911, '87'),
#  ('Stannis-Baratheon',
#   'Monford-Velaryon'): Text(0.1017038356512785, 0.06564843375235796, '3'),
#  ('Stannis-Baratheon',
#   'Mors-Umber'): Text(-0.020523507613688707, -0.09813275467604399, '7'),
#  ('Stannis-Baratheon',
#   'Myrcella-Baratheon'): Text(-0.03881987743079662, 0.05210254807025194, '3'),
#  ('Stannis-Baratheon',
#   'Orton-Merryweather'): Text(0.025473566725850105, 0.030713909305632114, '3'),
#  ('Stannis-Baratheon',
#   'Osney-Kettleblack'): Text(0.02501348964869976, 0.025260639376938343, '3'),
#  ('Stannis-Baratheon',
#   'Patchface'): Text(-0.08545535244047642, 0.028967791236937046, '6'),
#  ('Stannis-Baratheon',
#   'Petyr-Baelish'): Text(0.019488947466015816, 0.017744124867022038, '8'),
#  ('Stannis-Baratheon',
#   'Pycelle'): Text(0.01739216409623623, 0.014269930310547352, '12'),
#  ('Stannis-Baratheon',
#   'Pylos'): Text(-0.04278636910021305, 0.028562852181494236, '15'),
#  ('Stannis-Baratheon',
#   'Qyburn'): Text(0.027868928387761116, 0.003310573287308216, '3'),
#  ('Stannis-Baratheon',
#   'Ramsay-Snow'): Text(-0.05097092129290104, -0.09991530608385801, '8'),
#  ('Stannis-Baratheon',
#   'Randyll-Tarly'): Text(0.005873018875718117, -0.05389804672449827, '3'),
#  ('Stannis-Baratheon',
#   'Renly-Baratheon'): Text(0.010221799835562706, -0.008210779953515157, '110'),
#  ('Stannis-Baratheon',
#   'Richard-Horpe'): Text(-0.027005711570382118, -0.1383231384679675, '3'),
#  ('Stannis-Baratheon',
#   'Robert-Baratheon'): Text(-0.006199347786605358, 0.016045442782342434, '68'),
#  ('Stannis-Baratheon',
#   'Robett-Glover'): Text(-0.01759506412781775, -0.06573101039975882, '4'),
#  ('Stannis-Baratheon',
#   'Roose-Bolton'): Text(-0.010174680035561323, -0.04835557099431753, '18'),
#  ('Stannis-Baratheon',
#   'Roose-Ryswell'): Text(-0.1355911511927843, 0.0799075411632657, '3'),
#  ('Stannis-Baratheon',
#   'Salladhor-Saan'): Text(-0.04210752993822098, 0.015574109740555286, '20'),
#  ('Stannis-Baratheon',
#   'Samwell-Tarly'): Text(-0.09235803224146366, -0.06809246819466352, '37'),
#  ('Stannis-Baratheon',
#   'Sansa-Stark'): Text(-0.005350053310394287, 0.0039584022015333176, '11'),
#  ('Stannis-Baratheon',
#   'Selyse-Florent'): Text(-0.0886793602257967, -0.005702381255105138, '41'),
#  ('Stannis-Baratheon',
#   'Shae'): Text(0.005416177213191986, 0.035275776870548725, '3'),
#  ('Stannis-Baratheon',
#   'Shireen-Baratheon'): Text(-0.07072538696229458, 0.02876454684883356, '7'),
#  ('Stannis-Baratheon',
#   'Sigorn'): Text(-0.11892439611256123, -0.007532214280217886, '3'),
#  ('Stannis-Baratheon',
#   'Steffon-Baratheon'): Text(0.07554894499480724, -0.03989672940224409, '3'),
#  ('Stannis-Baratheon',
#   'Theomore'): Text(0.054559407755732536, -0.1012208117172122, '3'),
#  ('Stannis-Baratheon',
#   'Theon-Greyjoy'): Text(-0.032810330390930176, -0.0988963795825839, '10'),
#  ('Stannis-Baratheon',
#   'Tommen-Baratheon'): Text(0.000863468274474144, 0.014213013462722301, '16'),
#  ('Stannis-Baratheon',
#   'Tycho-Nestoris'): Text(-0.0656543355435133, -0.07902311068028212, '7'),
#  ('Stannis-Baratheon',
#   'Val'): Text(-0.08059474267065525, -0.024633205495774746, '15'),
#  ('Stannis-Baratheon',
#   'William-Foxglove'): Text(0.05700795166194439, -0.1275107217952609, '3'),
#  ('Stannis-Baratheon',
#   'Wyman-Manderly'): Text(0.009006895124912262, -0.04660122748464346, '19'),
#  ('Aegon-Targaryen-(son-of-Rhaegar)',
#   'Elia-Martell'): Text(0.12723828479647636, 0.13195053488016129, '7'),
#  ('Aegon-Targaryen-(son-of-Rhaegar)',
#   'Franklyn-Flowers'): Text(0.27195941656827927, 0.10746771097183228, '3'),
#  ('Aegon-Targaryen-(son-of-Rhaegar)',
#   'Haldon'): Text(0.12431435286998749, 0.12385139986872673, '14'),
#  ('Aegon-Targaryen-(son-of-Rhaegar)',
#   'Harry-Strickland'): Text(0.20035723596811295, 0.13782523572444916, '9'),
#  ('Aegon-Targaryen-(son-of-Rhaegar)',
#   'Jon-Connington'): Text(0.15641503781080246, 0.11908332630991936, '16'),
#  ('Aegon-Targaryen-(son-of-Rhaegar)',
#   'Lemore'): Text(0.14116012305021286, 0.12209384143352509, '10'),
#  ('Aegon-Targaryen-(son-of-Rhaegar)',
#   'Rhaegar-Targaryen'): Text(0.11746124923229218, 0.13049670308828354, '12'),
#  ('Aegon-Targaryen-(son-of-Rhaegar)',
#   'Rhaenys-Targaryen-(daughter-of-Rhaegar)'): Text(0.26358499377965927, 0.17839772999286652, '4'),
#  ('Aegon-Targaryen-(son-of-Rhaegar)',
#   'Rolly-Duckfield'): Text(0.13076820969581604, 0.12958911806344986, '11'),
#  ('Aegon-Targaryen-(son-of-Rhaegar)',
#   'Viserys-Targaryen'): Text(0.11295643448829651, 0.16357432305812836, '3'),
#  ('Aegon-Targaryen-(son-of-Rhaegar)',
#   'Yandry'): Text(0.14289385080337524, 0.12482327967882156, '6'),
#  ('Aegon-Targaryen-(son-of-Rhaegar)',
#   'Ysilla'): Text(0.14733058214187622, 0.13281814754009247, '4'),
#  ('Elia-Martell',
#   'Ashara-Dayne'): Text(0.2164267636835575, 0.21334770321846008, '3'),
#  ('Elia-Martell',
#   'Gregor-Clegane'): Text(0.052465860499069095, 0.09331063739955425, '7'),
#  ('Elia-Martell',
#   'Rhaegar-Targaryen'): Text(0.09431646391749382, 0.13036058843135834, '13'),
#  ('Franklyn-Flowers',
#   'Black-Balaq'): Text(0.5135384649038315, 0.056817831471562386, '3'),
#  ('Franklyn-Flowers',
#   'Jon-Connington'): Text(0.277991384267807, 0.09446438774466515, '4'),
#  ('Haldon', 'Benerro'): Text(0.12718874961137772, 0.09296530112624168, '4'),
#  ('Haldon',
#   'Illyrio-Mopatis'): Text(0.08521797508001328, 0.14836430177092552, '3'),
#  ('Haldon',
#   'Jon-Connington'): Text(0.13034632056951523, 0.1108480766415596, '13'),
#  ('Haldon', 'Lemore'): Text(0.11509140580892563, 0.11385859176516533, '4'),
#  ('Haldon', 'Pono'): Text(0.1376664713025093, 0.20879841223359108, '3'),
#  ('Haldon',
#   'Qavo-Nogarys'): Text(0.1122787594795227, 0.16115285083651543, '5'),
#  ('Haldon',
#   'Rolly-Duckfield'): Text(0.10469949245452881, 0.1213538683950901, '26'),
#  ('Haldon', 'Yandry'): Text(0.11682513356208801, 0.11658803001046181, '4'),
#  ('Haldon', 'Ysilla'): Text(0.12126186490058899, 0.12458289787173271, '5'),
#  ('Harry-Strickland',
#   'Jon-Connington'): Text(0.20638920366764069, 0.12482191249728203, '18'),
#  ('Harry-Strickland',
#   'Myles-Toyne'): Text(0.2810474783182144, 0.14279550313949585, '4'),
#  ('Jon-Connington',
#   'Illyrio-Mopatis'): Text(0.11731866002082825, 0.14359622821211815, '6'),
#  ('Jon-Connington',
#   'Lemore'): Text(0.1471920907497406, 0.10909051820635796, '11'),
#  ('Jon-Connington',
#   'Myles-Toyne'): Text(0.23710528016090393, 0.12405359372496605, '9'),
#  ('Jon-Connington',
#   'Nyessos-Vhassar'): Text(0.3366252928972244, 0.10682079568505287, '3'),
#  ('Jon-Connington',
#   'Rhaegar-Targaryen'): Text(0.12349321693181992, 0.11749337986111641, '7'),
#  ('Jon-Connington',
#   'Robert-Baratheon'): Text(0.09095182176679373, 0.07763702236115932, '8'),
#  ('Jon-Connington',
#   'Rolly-Duckfield'): Text(0.13680017739534378, 0.11658579483628273, '12'),
#  ('Jon-Connington',
#   'Yandry'): Text(0.14892581850290298, 0.11181995645165443, '9'),
#  ('Lemore',
#   'Rolly-Duckfield'): Text(0.12154526263475418, 0.11959630995988846, '5'),
#  ('Lemore', 'Yandry'): Text(0.13367090374231339, 0.11483047157526016, '5'),
#  ('Lemore', 'Ysilla'): Text(0.13810763508081436, 0.12282533943653107, '3'),
#  ('Rhaegar-Targaryen',
#   'Aerys-II-Targaryen'): Text(0.11055155098438263, 0.09597249329090118, '14'),
#  ('Rhaegar-Targaryen',
#   'Arstan'): Text(0.09505607187747955, 0.19974152743816376, '7'),
#  ('Rhaegar-Targaryen',
#   'Arthur-Dayne'): Text(0.21952881664037704, 0.1417972892522812, '3'),
#  ('Rhaegar-Targaryen',
#   'Barristan-Selmy'): Text(0.0667240098118782, 0.1541934832930565, '3'),
#  ('Rhaegar-Targaryen',
#   'Jorah-Mormont'): Text(0.07798604294657707, 0.17008833587169647, '14'),
#  ('Rhaegar-Targaryen',
#   'Lyanna-Stark'): Text(0.04317989130504429, 0.1064227856695652, '4'),
#  ('Rhaegar-Targaryen',
#   'Rhaella-Targaryen'): Text(0.15152328461408615, 0.22136910259723663, '3'),
#  ('Rhaegar-Targaryen',
#   'Robert-Baratheon'): Text(0.05199803318828344, 0.0890503991395235, '48'),
#  ('Rhaegar-Targaryen',
#   'Sansa-Stark'): Text(0.052847327664494514, 0.07696335855871439, '3'),
#  ('Rhaegar-Targaryen',
#   'Viserys-Targaryen'): Text(0.08003461360931396, 0.1619843766093254, '15'),
#  ('Rolly-Duckfield',
#   'Illyrio-Mopatis'): Text(0.09167183190584183, 0.15410201996564865, '6'),
#  ('Rolly-Duckfield',
#   'Yandry'): Text(0.12327899038791656, 0.12232574820518494, '12'),
#  ('Rolly-Duckfield',
#   'Ysilla'): Text(0.12771572172641754, 0.13032061606645584, '9'),
#  ('Viserys-Targaryen',
#   'Aerys-II-Targaryen'): Text(0.10604673624038696, 0.129050113260746, '3'),
#  ('Viserys-Targaryen',
#   'Doran-Martell'): Text(0.0018792971968650818, 0.1915275603532791, '3'),
#  ('Viserys-Targaryen',
#   'Doreah'): Text(0.08773008361458778, 0.2561566010117531, '3'),
#  ('Viserys-Targaryen',
#   'Drogo'): Text(0.09149816259741783, 0.23725342005491257, '26'),
#  ('Viserys-Targaryen',
#   'Illyrio-Mopatis'): Text(0.0738600566983223, 0.18808722496032715, '14'),
#  ('Viserys-Targaryen',
#   'Irri'): Text(0.07850568369030952, 0.24464047700166702, '5'),
#  ('Viserys-Targaryen',
#   'Jorah-Mormont'): Text(0.0734812282025814, 0.2031659558415413, '15'),
#  ('Viserys-Targaryen',
#   'Rhaella-Targaryen'): Text(0.14701846987009048, 0.25444672256708145, '3'),
#  ('Viserys-Targaryen',
#   'Robert-Baratheon'): Text(0.04749321844428778, 0.12212801910936832, '16'),
#  ('Yandry', 'Ysilla'): Text(0.13984136283397675, 0.12555477768182755, '14'),
#  ('Aegon-V-Targaryen',
#   'Aemon-Targaryen-(Maester-Aemon)'): Text(-0.27205394953489304, -0.0850706472992897, '6'),
#  ('Aemon-Targaryen-(Maester-Aemon)',
#   'Alleras'): Text(-0.19590359181165695, -0.23452205583453178, '4'),
#  ('Aemon-Targaryen-(Maester-Aemon)',
#   'Alliser-Thorne'): Text(-0.14063264802098274, -0.06213863007724285, '7'),
#  ('Aemon-Targaryen-(Maester-Aemon)',
#   'Bowen-Marsh'): Text(-0.17138545215129852, -0.07360431924462318, '4'),
#  ('Aemon-Targaryen-(Maester-Aemon)',
#   'Chett'): Text(-0.18894287943840027, -0.11532260850071907, '9'),
#  ('Aemon-Targaryen-(Maester-Aemon)',
#   'Clydas'): Text(-0.1787087246775627, -0.07921332493424416, '33'),
#  ('Aemon-Targaryen-(Maester-Aemon)',
#   'Cotter-Pyke'): Text(-0.1657373234629631, -0.08287224173545837, '3'),
#  ('Aemon-Targaryen-(Maester-Aemon)',
#   'Daeron-II-Targaryen'): Text(-0.16732843220233917, 0.05359278991818428, '3'),
#  ('Aemon-Targaryen-(Maester-Aemon)',
#   'Dareon'): Text(-0.19408166408538818, -0.10477493330836296, '5'),
#  ('Aemon-Targaryen-(Maester-Aemon)',
#   'Denys-Mallister'): Text(-0.1780211180448532, -0.0970558151602745, '4'),
#  ('Aemon-Targaryen-(Maester-Aemon)',
#   'Donal-Noye'): Text(-0.178902305662632, -0.06547212600708008, '11'),
#  ('Aemon-Targaryen-(Maester-Aemon)',
#   'Eddison-Tollett'): Text(-0.1849193274974823, -0.08913937583565712, '3'),
#  ('Aemon-Targaryen-(Maester-Aemon)',
#   'Gilly'): Text(-0.16978422552347183, -0.09658919647336006, '20'),
#  ('Aemon-Targaryen-(Maester-Aemon)',
#   'Grenn'): Text(-0.17475082725286484, -0.08853433653712273, '5'),
#  ('Aemon-Targaryen-(Maester-Aemon)',
#   'Hobb'): Text(-0.18630243837833405, -0.06379775516688824, '3'),
#  ('Aemon-Targaryen-(Maester-Aemon)',
#   'Janos-Slynt'): Text(-0.11911267414689064, -0.04402324231341481, '5'),
#  ('Aemon-Targaryen-(Maester-Aemon)',
#   'Jeor-Mormont'): Text(-0.15046607702970505, -0.07782575488090515, '25'),
#  ('Aemon-Targaryen-(Maester-Aemon)',
#   'Jon-Snow'): Text(-0.15611012279987335, -0.07009510323405266, '110'),
#  ('Aemon-Targaryen-(Maester-Aemon)',
#   'Maekar-I-Targaryen'): Text(-0.3167026415467262, -0.07923642918467522, '3'),
#  ('Aemon-Targaryen-(Maester-Aemon)',
#   'Mance-Rayder'): Text(-0.16277208179235458, -0.08563540130853653, '5'),
#  ('Aemon-Targaryen-(Maester-Aemon)',
#   'Owen'): Text(-0.1878495067358017, -0.05845351330935955, '3'),
#  ('Aemon-Targaryen-(Maester-Aemon)',
#   'Pypar'): Text(-0.1763273999094963, -0.08485008403658867, '5'),
#  ('Aemon-Targaryen-(Maester-Aemon)',
#   'Robert-Baratheon'): Text(-0.07693018112331629, -0.015444600954651833, '5'),
#  ('Aemon-Targaryen-(Maester-Aemon)',
#   'Samwell-Tarly'): Text(-0.1630888655781746, -0.09958251193165779, '99'),
#  ('Aemon-Targaryen-(Maester-Aemon)',
#   'Wynton-Stout'): Text(-0.31666190177202225, -0.06490561738610268, '3'),
#  ('Alleras', 'Armen'): Text(-0.237571120262146, -0.45708082616329193, '5'),
#  ('Alleras',
#   'Leo-Tyrell'): Text(-0.22027891129255295, -0.42493680119514465, '7'),
#  ('Alleras', 'Marwyn'): Text(-0.2316797971725464, -0.36012299358844757, '3'),
#  ('Alleras',
#   'Mollander'): Text(-0.2399829775094986, -0.47001348435878754, '7'),
#  ('Alleras',
#   'Pate-(novice)'): Text(-0.2106996774673462, -0.5029359310865402, '8'),
#  ('Alleras', 'Roone'): Text(-0.2508707642555237, -0.4629470258951187, '6'),
#  ('Alleras',
#   'Samwell-Tarly'): Text(-0.1856754571199417, -0.2540213242173195, '8'),
#  ('Alliser-Thorne',
#   'Bowen-Marsh'): Text(-0.13870109990239143, -0.05565970577299595, '3'),
#  ('Alliser-Thorne',
#   'Grenn'): Text(-0.14206647500395775, -0.07058972306549549, '3'),
#  ('Alliser-Thorne',
#   'Halder'): Text(-0.1538155861198902, -0.07397680915892124, '4'),
#  ('Alliser-Thorne',
#   'Janos-Slynt'): Text(-0.08642832189798355, -0.026078628841787577, '13'),
#  ('Alliser-Thorne',
#   'Jeor-Mormont'): Text(-0.11778172478079796, -0.059881141409277916, '13'),
#  ('Alliser-Thorne',
#   'Jon-Snow'): Text(-0.12342577055096626, -0.05215048976242542, '63'),
#  ('Alliser-Thorne',
#   'Mance-Rayder'): Text(-0.1300877295434475, -0.0676907878369093, '6'),
#  ('Alliser-Thorne',
#   'Pypar'): Text(-0.14364304766058922, -0.06690547056496143, '4'),
#  ('Alliser-Thorne',
#   'Qhorin-Halfhand'): Text(-0.1533513404428959, -0.06787833012640476, '4'),
#  ('Alliser-Thorne',
#   'Rast'): Text(-0.17072256281971931, -0.0705017950385809, '5'),
#  ('Alliser-Thorne',
#   'Samwell-Tarly'): Text(-0.1304045133292675, -0.08163789846003056, '12'),
#  ...}

# %% [markdown]
# ## Subsetting the Graph
#
# As you can see, the above graph is undoubtedly noisy, making it difficult to discern any useful patterns. As such, reset the graph and only add edges whose weight is 75 or greater. From there, redraw the graph. To further help with the display, try using `nx.spring_layout(G)` for the position. To jazz it up, try and recolor those nodes which you identified as bridge or bottleneck nodes to communication.

# %%
# Your code here
threshold = 75
colors = []
# Create an empty graph instance
G = nx.Graph()
# Read edge lists into dataframes
for row in df.index:
    source = df['Source'][row]
    target = df['Target'][row]
    weight = df['weight'][row]
    if weight >= threshold:
        G.add_edge(source, target, weight=weight)
edge_labels = nx.get_edge_attributes(G, 'weight')
for node in G.nodes:
    if node in centrality.index[:10]:
        colors.append('#ffd43d')
    else:
        colors.append('#1cf0c7')
plt.figure(figsize=(12,12))
nx.draw(G, with_labels=True, pos=nx.spring_layout(G), alpha=0.8, node_color=colors, node_size=700)
nx.draw_networkx_edge_labels(G, pos=nx.spring_layout(G), edge_labels=edge_labels)
# Out:
# {('Aemon-Targaryen-(Maester-Aemon)',
#   'Jon-Snow'): Text(0.3346693551602214, -0.1277012029280668, '110'),
#  ('Aemon-Targaryen-(Maester-Aemon)',
#   'Samwell-Tarly'): Text(0.3705202219049841, -0.12666104946872758, '99'),
#  ('Jon-Snow',
#   'Bran-Stark'): Text(0.2552431542046337, -0.14792106906882552, '90'),
#  ('Jon-Snow',
#   'Jeor-Mormont'): Text(0.3082746376359331, -0.1191316304663935, '174'),
#  ('Jon-Snow',
#   'Mance-Rayder'): Text(0.323213556359775, -0.16270694020230592, '112'),
#  ('Jon-Snow', 'Pypar'): Text(0.33945727457469077, -0.1724127479465845, '77'),
#  ('Jon-Snow',
#   'Robb-Stark'): Text(0.23492749595533752, -0.11600416121013533, '91'),
#  ('Jon-Snow',
#   'Samwell-Tarly'): Text(0.33362026578335435, -0.14172036983861264, '228'),
#  ('Jon-Snow',
#   'Stannis-Baratheon'): Text(0.2417529202810832, -0.19642520177287248, '91'),
#  ('Jon-Snow',
#   'Ygritte'): Text(0.33039383695319524, -0.10629873949374968, '80'),
#  ('Samwell-Tarly',
#   'Gilly'): Text(0.41405959467296494, -0.1397742347511022, '84'),
#  ('Arya-Stark',
#   'Gendry'): Text(-0.3955854026590454, -0.16207996008204573, '82'),
#  ('Arya-Stark',
#   'Hot-Pie'): Text(-0.385330253072233, -0.18557612772438936, '76'),
#  ('Arya-Stark',
#   'Sansa-Stark'): Text(-0.3184563722283985, -0.13160027258401696, '155'),
#  ('Sansa-Stark',
#   'Cersei-Lannister'): Text(-0.23142594260698318, -0.0988240559057965, '95'),
#  ('Sansa-Stark',
#   'Joffrey-Baratheon'): Text(-0.25902936063917714, -0.09707320754064397, '222'),
#  ('Sansa-Stark',
#   'Tyrion-Lannister'): Text(-0.2741590847383275, -0.08061165536394307, '118'),
#  ('Barristan-Selmy',
#   'Daenerys-Targaryen'): Text(-0.24687836564018867, 0.9728880683340122, '83'),
#  ('Daenerys-Targaryen',
#   'Drogo'): Text(-0.2540270914332651, 0.9389189576447302, '123'),
#  ('Daenerys-Targaryen',
#   'Hizdahr-zo-Loraq'): Text(-0.21392983937332588, 0.9703586675927715, '96'),
#  ('Daenerys-Targaryen',
#   'Jorah-Mormont'): Text(-0.21348628366924496, 0.9336485056754182, '161'),
#  ('Bran-Stark',
#   'Hodor'): Text(0.21798578211516723, -0.1342708076057089, '209'),
#  ('Bran-Stark',
#   'Jojen-Reed'): Text(0.23877984434213456, -0.17288564424332714, '112'),
#  ('Bran-Stark',
#   'Luwin'): Text(0.22207066898274422, -0.1828157882744908, '116'),
#  ('Bran-Stark',
#   'Meera-Reed'): Text(0.18714155197286247, -0.14924830665137093, '123'),
#  ('Bran-Stark',
#   'Rickon-Stark'): Text(0.19488469155383828, -0.1757982294683978, '129'),
#  ('Bran-Stark',
#   'Robb-Stark'): Text(0.19240125112137962, -0.12116470698100895, '169'),
#  ('Robb-Stark',
#   'Catelyn-Stark'): Text(0.11456541450082244, -0.09275567143310284, '128'),
#  ('Robb-Stark',
#   'Theon-Greyjoy'): Text(0.18160515051903836, -0.029406294496577216, '76'),
#  ('Brienne-of-Tarth',
#   'Jaime-Lannister'): Text(-0.24111984837706985, 0.0223406937518683, '111'),
#  ('Jaime-Lannister',
#   'Cersei-Lannister'): Text(-0.20764881598778187, -0.04989294723228363, '130'),
#  ('Jaime-Lannister',
#   'Tyrion-Lannister'): Text(-0.2503819581191262, -0.03168054669043021, '113'),
#  ('Bronn',
#   'Tyrion-Lannister'): Text(-0.3022033124256886, -0.03654236067605529, '137'),
#  ('Tyrion-Lannister',
#   'Cersei-Lannister'): Text(-0.22647726872152585, -0.071021290786534, '209'),
#  ('Tyrion-Lannister',
#   'Joffrey-Baratheon'): Text(-0.25408068675371975, -0.06927044242138147, '219'),
#  ('Tyrion-Lannister',
#   'Tywin-Lannister'): Text(-0.3081492221404917, -0.054077237069455414, '117'),
#  ('Tyrion-Lannister',
#   'Varys'): Text(-0.2922839342581832, -0.021282250873668876, '107'),
#  ('Catelyn-Stark',
#   'Eddard-Stark'): Text(-0.008991422379878378, -0.11006496335003221, '88'),
#  ('Eddard-Stark',
#   'Cersei-Lannister'): Text(-0.12938610373974987, -0.10655003714228248, '91'),
#  ('Eddard-Stark',
#   'Petyr-Baelish'): Text(-0.0886423092170355, -0.1606841228304325, '85'),
#  ('Eddard-Stark',
#   'Robert-Baratheon'): Text(-0.07576220341558271, -0.13620980095077967, '334'),
#  ('Cersei-Lannister',
#   'Joffrey-Baratheon'): Text(-0.21134754462237543, -0.08748284296323489, '173'),
#  ('Cersei-Lannister',
#   'Margaery-Tyrell'): Text(-0.17327889740169883, -0.054161468730058455, '79'),
#  ('Cersei-Lannister',
#   'Robert-Baratheon'): Text(-0.13012022626601433, -0.11889345513688464, '134'),
#  ('Cersei-Lannister',
#   'Tommen-Baratheon'): Text(-0.2014673480986749, -0.10958063914418309, '111'),
#  ('Joffrey-Baratheon',
#   'Tommen-Baratheon'): Text(-0.22907076613086885, -0.10782979077903054, '77'),
#  ('Robert-Baratheon',
#   'Renly-Baratheon'): Text(-0.007083527574290729, -0.18354114132510693, '80'),
#  ('Davos-Seaworth',
#   'Stannis-Baratheon'): Text(0.18317496113269452, -0.28351237371011984, '131'),
#  ('Stannis-Baratheon',
#   'Melisandre'): Text(0.20483844951066488, -0.2939242793235747, '87'),
#  ('Stannis-Baratheon',
#   'Renly-Baratheon'): Text(0.12403285615842023, -0.23430947197631252, '110'),
#  ('Ramsay-Snow',
#   'Theon-Greyjoy'): Text(0.19729020858423876, 0.06679640984708414, '101')}

# %% [markdown]
# ## Summary
#
# In this lab, we looked at different centrality measures of the graph data for the ASIOF dataset. We also compared these measures to see how they correlate with each other. We also saw in practice, the difference between taking the weighted centrality measures and how it may effect the results.
